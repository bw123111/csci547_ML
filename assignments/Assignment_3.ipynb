# %% [markdown]
# # Assignment 3 - Supervised Learning: model training and evaluation

# %% [markdown]
# ## *Bella Wengappuly*
# Netid: bw165311
#
#
#
# Note: this assignment falls under collaboration Mode 2: Individual Assignment – Collaboration Permitted. Please refer to the syllabus for additional information.

# %% [markdown]
# Instructions for all assignments can be found [here](https://github.com/kylebradbury/ids705/blob/master/assignments/_Assignment%20Instructions.ipynb), and is also linked to from the [course syllabus](https://kylebradbury.github.io/ids705/index.html).
#
# Total points in the assignment add up to 90; an additional 10 points are allocated to presentation quality.

# %% [markdown]
# # Learning Objectives:
# This assignment will provide structured practice to help enable you to...
# 1. Understand the primary workflow in machine learning: (1) identifying a hypothesis function set of models, (2) determining a loss/cost/error/objective function to minimize, and (3) minimizing that function through gradient descent
# 2. Understand the inner workings of logistic regression and how linear models for classification can be developed.
# 3. Gain practice in implementing machine learning algorithms from the most basic building blocks to understand the math and programming behind them to achieve practical proficiency with the techniques
# 4. Implement batch gradient descent and become familiar with how that technique is used and its dependence on the choice of learning rate
# 5. Evaluate supervised learning algorithm performance through ROC curves and using cross validation
# 6. Apply regularization to linear models to improve model generalization performance

# %% [markdown]
# # 1
# ## Classification using logistic regression: build it from the ground up
# **[60 points]**
#
# This exercise will walk you through the full life-cycle of a supervised machine learning classification problem. Classification problem consists of two features/predictors (e.g. petal width and petal length) and your goal is to predict one of two possible classes (class 0 or class 1). You will build, train, and evaluate the performance of a logistic regression classifier on the data provided. Before you begin any modeling, you'll load and explore your data in Part I to familiarize yourself with it - and check for any missing or erroneous data. Then, in Part II, we will review an appropriate hypothesis set of functions to fit to the data: in this case, logistic regression. In Part III, we will derive an appropriate cost function for the data (spoiler alert: it's cross-entropy) as well as the gradient descent update equation that will allow you to optimize that cost function to identify the parameters that minimize the cost for the training data. In Part IV, all the pieces come together and you will implement your logistic regression model class including methods for fitting the data using gradient descent. Using that model you'll test it out and plot learning curves to verify the model learns as you train it and to identify and appropriate learning rate hyperparameter. Lastly, in Part V you will apply the model you designed, implemented, and verified to your actual data and evaluate and visualize its generalization performance as compared to a KNN algorithm. **When complete, you will have accomplished learning objectives 1-5 above!**
#
# ### I. Load, prepare, and plot your data
# You are given some data for which you are tasked with constructing a classifier. The first step when facing any machine learning project: look at your data!
#
# **(a)** Load the data.
# - In the data folder in the same directory of this notebook, you'll find the data in `A3_Q1_data.csv`. This file contains the binary class labels, $y$, and the features $x_1$ and $x_2$.
# - Divide your data into a training and testing set where the test set accounts for 30 percent of the data and the training set the remaining 70 percent.
# - Plot the training data by class.
# - Comment on the data: do the data appear separable? May logistic regression be a good choice for these data? Why or why not?
#
# **(b)** Do the data require any preprocessing due to missing values, scale differences (e.g. different ranges of values), etc.? If so, how did you handle these issues?
#
# Next, we walk through our key steps for model fitting: choose a hypothesis set of models to train (in this case, logistic regression); identify a cost function to measure the model fit to our training data; optimize model parameters to minimize cost (in this case using gradient descent). Once we've completed model fitting, we will evaluate the performance of our model and compare performance to another approach (a KNN classifier).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

data = pd.read_csv('https://raw.githubusercontent.com/bw123111/csci547_ML/refs/heads/main/assignments/data/A3_Q1_data.csv')
# data.head()

X_train, X_test, y_train, y_test = train_test_split(data[['x1', 'x2']], data['y'], test_size=0.3, random_state=42)

# X_train.head()

plt.scatter(X_train['x1'], X_train['x2'])
plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Training Data')
plt.show()

# %%
data.describe()
# Out:
#                x1          x2           y
# count  200.000000  200.000000  200.000000
# mean     0.151376   -0.385426    0.485000
# std      1.411722    1.217490    0.501029
# min     -3.210005   -3.193456    0.000000
# 25%     -0.912029   -1.341047    0.000000
# 50%      0.112286   -0.479684    0.000000
# 75%      1.174400    0.495114    1.000000
# max      3.867647    3.103541    1.000000

# %%
data.isna().sum()
# Out:
# x1    0
# x2    0
# y     0
# dtype: int64

# %% [markdown]
# **ANSWER**
# The data does not appear very separable, logistic regression may be a better choice than clustering since the data has a continuous oblong spread, rather than clumped points.
#
# The data is well matched in scale (about -3 to 4) and there are no NA values in the data. If there was a significant scale issue, I would use scikit learn StandardScaler on the X training values, then separately on the test X values.

# %% [markdown]
# ### II. Implement gradient descent and your logistic regression algorithm
#
# **(a)** Implement your logistic regression model.
# - You are provided with a template, below, for a class with key methods to help with your model development. It is modeled on the Scikit-Learn convention. For this, you only need to create a version of logistic regression for the case of two feature variables (i.e. two predictors).
# - Create a method called `sigmoid` that calculates the sigmoid function
# - Create a method called `cost` that computes the cost function $C(\mathbf{w})$ for a given dataset and corresponding class labels. This should be the **average cost** (make sure your total cost is divided by your number of samples in the dataset).
# - Create a method called `gradient_descent` to run **one step** of gradient descent on your training data. We'll refer to this as "batch" gradient descent since it takes into account the gradient based on all our data at each iteration of the algorithm.
# - Create a method called `fit` that fits the model to the data (i.e. sets the model parameters to minimize cost) using your `gradient_descent` method. In doing this we'll need to make some assumptions about the following:
#     - Weight initialization. What should you initialize the model parameters to? For this, randomly initialize the weights to a different values between 0 and 1.
#     - Learning rate. How slow/fast should the algorithm step towards the minimum? This you will vary in a later part of this problem.
#     - Stopping criteria. When should the algorithm be finished searching for the optimum? There are two stopping criteria: small changes in the gradient descent step size and a maximum number of iterations. The first is whether there was a sufficiently small change in the gradient; this is evaluated as whether the magnitude of the step that the gradient descent algorithm takes changes by less than $10^{-6}$ between iterations. Since we have a weight vector, we can compute the change in the weight by evaluating the $L_2$ norm (Euclidean norm) of the change in the vector between iterations.  The second criterion is met if a maximum number of iterations has been reach (5,000 in this case, to prevent infinite loops from poor choices of learning rates).
#     - Design your approach so that at each step in the gradient descent algorithm you evaluate the cost function for both the training and the test data for each new value for the model weights. You should be able to plot cost vs gradient descent iteration for both the training and the test data. This will allow you to plot "learning curves" that can be informative for how the model training process is proceeding.
# - Create a method called `predict_proba` that predicts confidence scores (that can be thresholded into the predictions of the `predict` method.
# - Create a method called `predict` that makes predictions based on the trained model, selecting the most probable class, given the data, as the prediction, that is class that yields the larger $P(y|\mathbf{x})$.
# - (Optional, but recommended) Create a method called `learning_curve` that produces the cost function values that correspond to each step from a previously run gradient descent operation.
# - (Optional, but recommended) Create a method called `prepare_x` which appends a column of ones as the first feature of the dataset $\mathbf{X}$ to account for the bias term ($x_{i,1}=1$).
#
# This structure is strongly encouraged; however, you're welcome to adjust this to your needs (adding helper methods, modifying parameters, etc.).

# %% [markdown]
# **ANSWER**
# Credit for helping me through this problem while tying the code back to the core mathematical concepts goes to [this youtube video.](https://www.youtube.com/watch?v=YYEJ_GUguHw)

# %% [markdown]
# ***Take 1***
# This class is closely based on the youtube video, allowing me to get familiar with the process. Many of the more detailed functionalities requested by the assignment are not included...On to take 2!

# %%
# from matplotlib.patches import draw_bbox
# class Logistic_regression:
#   # define function params and initial values
#   def __init__(self, lr=0.001, n_iters=5000):
#     self.lr = lr
#     self.n_iters = n_iters
#     self.weights = None
#     self.bias = None
#     self.saved_dw = [] # Since this is a small problem, we can save the weights
#                           #  at each iteration of gradient descent to build our
#                           #  learning curves

# # define sigmoid calculation (calc for predicting a single y based on X)
#   def sigmoid(self, X):
#     return 1 / (1 + np.exp(-X))

#   # predict sigmoidal probabilities y
#   def predict_proba(self, X):
#     linreg_pred = np.dot(X, self.weights) + self.bias # function for linear model
#     y_pred = self.sigmoid(linreg_pred)   # function to calculate pred y
#     return y_pred


#   def cost(self, X, y):
#     n_samples = X.shape[0]
#     y_pred = self.predict_proba(X)

#     # Add small epsilon to prevent log(0)
#     epsilon = 1e-15
#     y_pred = np.clip(y_pred, epsilon, 1 - epsilon)

#     # Binary cross-entropy cost
#     cost = -np.mean(y * np.log(y_pred) + (1 - y) * np.log(1 - y_pred))
#     return cost



#   # fit entire model!
#   def fit(self, X, y, verbose=False):

#       n_samples, n_features = X.shape

#       # define initial weights and biases as 0
#       self.weights = np.zeros(n_features)
#       self.bias = 0
#       self.saved_dw.append(0)

#       # gradient descent
#       for _ in range(self.n_iters):
#         if _ > 5000:
#           break
#         if verbose==True:
#           print(f"weight: {self.weights}, bias: {self.bias}\n")

#         # calculate prediction
#         y_pred = self.predict(X)

#         # calculate change in weight AKA weight cost
#         dw = (1/n_samples) * np.dot(X.T, (y_pred - y))
#         # calculate change in bias AKA bias cost
#         db = (1/n_samples) * np.sum(y_pred - y)

#         # update weights and biases based on cost functions above
#         self.weights -= self.lr * dw
#         self.bias -= self.lr * db
#         self.saved_dw.append(dw)

# # predicts classes of each probabilistic prediction
# def predict(self, X, threshold=0.5):
#   return [0 if y<= threshold else 1 for y in self.predict_proba(X)]

# # Stores the learning curves from saved weights from gradient descent
# def learning_curve(self, X, y):
#     # returns the value of the cost function from each step in gradient descent
#     #  from the last model fitting process
#   return self.saved_dw

# %% [markdown]
# ***Take 2***
# Here, I used the template provided and it turned out pretty long. I asked Claude AI to help me interpret the question and comments, as I wasn't sure what some of them were asking (e.g. scalar of the magnitude of the Euclidean norm). The AI provided the relevant LaTeX equations for sigmoid, cost, gradient, from which I wrote the python code version.
#
# I had a few errors along the way, a Runtime Error and then the code took foreeever so I created some extra self variables for optimization. I also mushed the training and testing model fitting together, so you can run it just once. Did it for kicks to see if it would work, not the most generalizeably optimal solution.

# %%
# Logistic regression class
class Logistic_regression:
    # Class constructor
    def __init__(self):
        self.w = None     # logistic regression weights
        self.saved_w = [] # Since this is a small problem, we can save the weights
                          #  at each iteration of gradient descent to build our
                          #  learning curves
        self.saved_train_costs = []  # Store training costs computed during fit
        self.saved_test_costs = []   # Store test costs computed during fit
        # returns nothing
        pass

    # Method for calculating the sigmoid function of w^T X for an input set of weights
    def sigmoid(self, X, w):
      z = np.dot(X, w)
      z = np.clip(z, -500, 500)  # Prevent extreme values, had a Runtime error before...
      return 1/(1+np.exp(-z))
        # returns the value of the sigmoid

    # Cost function for an input set of weights
    def cost(self, X, y, w):
        # Add small epsilon to prevent log(0) (undefined)
        epsilon = 1e-15
        y_pred = self.sigmoid(X, w)
        y_pred = np.clip(y_pred, epsilon, 1 - epsilon)

        return (-np.mean(y*np.log(y_pred) + (1-y)*np.log(1-y_pred)))
        # this is the coded version of the gradient descent cost function from lecture.
        # y hat is the prediction, i.e. the sigmoid function.
        # returns the average cross entropy cost

    # Update the weights in an iteration of gradient descent, return difference in weights
    def gradient_descent(self, X, y, lr):
        n_samples = X.shape[0]

        # calc predictions
        y_pred = self.sigmoid(X, self.w)

        # calc gradient
        gradient = (1/n_samples) * np.dot(X.T, (y_pred - y))

        # Store old weights to calc change
        old_w = self.w.copy()

        # Update weights
        self.w = self.w - lr * gradient

        # calc magnitude of change
        weight_change = np.linalg.norm(self.w - old_w)

        # returns a scalar of the magnitude of the Euclidean norm
        #  of the change in the weights during one gradient descent step
        return weight_change

    # Fit the logistic regression model to the data through gradient descent
    def fit(self, X, y, w_init, lr, X_test=None, y_test=None, delta_thresh=1e-6, max_iter=5000, verbose=False):
        # Note the verbose flag enables you to print out the weights at each iteration
        #  (optional - but may help with one of the questions)

        # Initialize weights and clear saved costs
        self.w = w_init.copy()
        self.saved_w = [self.w.copy()]  # Save initial weights
        self.saved_train_costs = [self.cost(X, y, self.w)]  # Save initial train cost

        # Save initial test cost if test data provided
        if X_test is not None and y_test is not None:
            self.saved_test_costs = [self.cost(X_test, y_test, self.w)]
        else:
            self.saved_test_costs = []

        # Gradient descent loop
        for iteration in range(max_iter):
            # Perform one step of gradient descent
            weight_change = self.gradient_descent(X, y, lr)

            # Save weights and costs at each iteration
            self.saved_w.append(self.w.copy())
            self.saved_train_costs.append(self.cost(X, y, self.w))

            # Save test cost if test data provided
            if X_test is not None and y_test is not None:
                self.saved_test_costs.append(self.cost(X_test, y_test, self.w))

            if verbose:
                print(f"Iteration {iteration}: Cost = {self.saved_train_costs[-1]:.6f}, Weight change = {weight_change:.8f}")

            # Stopping criterion: check if change in weights is small enough
            if weight_change < delta_thresh:
                if verbose:
                    print(f"Converged at iteration {iteration}")
                break

        # returns nothing
        pass

    # Use the trained model to predict the confidence scores (prob of positive class in this case)
    def predict_proba(self, X):
        # returns the confidence score for the each sample
        return self.sigmoid(X, self.w)

    # Use the trained model to make binary predictions
    def predict(self, X, thresh=0.5):
        # returns a binary pred per sample based on probability pred
        probas = self.predict_proba(X)
        return np.array([0 if p <= thresh else 1 for p in probas])

    # Stores the learning curves from saved weights from gradient descent
    def learning_curve(self, X=None, y=None):

        # If only X and y, calc costs from saved weights (slow!)
        if X is not None and y is not None:
            return [self.cost(X, y, w) for w in self.saved_w]

        # else  return saved costs (fast!!)
        # returns the value of the cost function from each step in gradient descent
        # from the last model fitting run
        return self.saved_train_costs, self.saved_test_costs

    # Appends a column of ones as the first feature to account for the bias term
    def prepare_x(self, X):
        # returns the X with a new feature of all ones (a column that is the new column 0)
        n_samples = X.shape[0]
        ones = np.ones((n_samples, 1))
        return np.hstack([ones, X])

# %% [markdown]
# **(b)** Choose a learning rate and fit your model. Learning curves are a plot of metrics of model performance evaluated through the process of model training to provide insight about how model training is proceeding. Show the learning curves for the gradient descent process for learning rates of $\{10^{-2}, 10^{-4}, 10^{-6}\}$. For each learning rate plot the learning curves by plotting **both the training and test data average cost** as a function of each iteration of gradient descent. You should run the model fitting process until it completes (up to 5,000 iterations of gradient descent). Each of the 6 resulting curves (train and test average cost for each learning rate) should be plotted on the same set of axes for direct comparison. *Note: make sure you're using average cost per sample, not total cost*
# - Try running this process for a really big learning rate for this problem: $10^0$. Look at the weights that the fitting process generates over the first 50 iterations and how they change. You may simply print these first 50 iterations as output or plot them. What happens and why?
# - What is the impact that the different values of learning has on the speed of the process and the results?
# - Of the options explored, what learning rate do you prefer and why?
# - Use your chosen learning rate for the remainder of this problem.

# %%
learning_rates = [1e-2, 1e-4, 1e-6]

plt.figure(figsize=(14, 8))

# Dict to store results
results = {}

# Train model for each learning rate
for lr in learning_rates:
    print(f"Training with learning rate: {lr}")

    model = Logistic_regression()
    X_train_prep = model.prepare_x(X_train)
    X_test_prep = model.prepare_x(X_test)

    # Initialize weights randomly between 0 and 1 according to instructions
    np.random.seed(42)  # For reproducibility across runs
    w_init = np.random.rand(X_train_prep.shape[1])

    # Fit the model - add test data to compute costs during training and testing
    model.fit(X_train_prep, y_train, w_init, lr=lr,
              X_test=X_test_prep, y_test=y_test,
              delta_thresh=1e-6, max_iter=5000, verbose=False)

    # Get learning curves
    train_costs, test_costs = model.learning_curve()

    # Store results
    results[lr] = {
        'train_costs': train_costs,
        'test_costs': test_costs,
        'iterations': len(train_costs)
    }

    # Plot training curve
    plt.plot(range(len(train_costs)), train_costs,
             label=f'Train (lr={lr})', linewidth=2, linestyle='-')

    # Plot test curve
    plt.plot(range(len(test_costs)), test_costs,
             label=f'Test (lr={lr})', linewidth=2, linestyle='--')

# Customize plot
plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Average Cost', fontsize=12)
plt.title('Learning Curves: Training and Test Cost vs Iteration\nfor Different Learning Rates',
          fontsize=14, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Optional: Use log scale for x-axis if curves converge quickly
# plt.xscale('log')

plt.show()

# Print summary comparison (used Claude AI to generate the nice tabular spacing/format)
print("SUMMARY")
print(f"{'Learning Rate':<15} {'Iterations':<12} {'Final Train Cost':<18} {'Final Test Cost':<18}")

for lr in learning_rates:
    iterations = results[lr]['iterations'] - 1
    final_train = results[lr]['train_costs'][-1]
    final_test = results[lr]['test_costs'][-1]
    print(f"{lr:<15.0e} {iterations:<12} {final_train:<18.6f} {final_test:<18.6f}")
# Out:
# Training with learning rate: 0.01
# Training with learning rate: 0.0001
# Training with learning rate: 1e-06
# SUMMARY
# Learning Rate   Iterations   Final Train Cost   Final Test Cost
# 1e-02           5000         0.272863           1.893913
# 1e-04           5000         1.231647           0.538727
# 1e-06           5000         1.765450           0.415039

# %% [markdown]
# I gave Claude AI the following code and asked it to format it better for printing. It returned the code in use to provide the SUMMARY below the plot.
#
# ```
#     print(f"Converged after {len(train_costs)-1} iterations")
#     print(f"Final training cost: {train_costs[-1]:.6f}")
#     print(f"Final test cost: {test_costs[-1]:.6f}\n")
# ```
# New formatted version:
# ```
# # Print summary comparison (used Claude AI to generate the nice tabular spacing/format)
# print("SUMMARY")
# print(f"{'Learning Rate':<15} {'Iterations':<12} {'Final Train Cost':<18} {'Final Test Cost':<18}")
#
# for lr in learning_rates:
#     iterations = results[lr]['iterations'] - 1
#     final_train = results[lr]['train_costs'][-1]
#     final_test = results[lr]['test_costs'][-1]
#     print(f"{lr:<15.0e} {iterations:<12} {final_train:<18.6f} {final_test:<18.6f}")
# ```

# %%
model = Logistic_regression()

# Prepare X with bias term
X_train_prep = model.prepare_x(X_train)

# Initialize weights randomly between 0 and 1
w_init = np.random.rand(X_train_prep.shape[1])

# Train model
model.fit(X_train_prep, y_train, w_init, lr=0.1, verbose=True)

# Make predictions
X_test = np.random.randn(30, 2)
y_test = (X_test[:, 0] + X_test[:, 1] > 0).astype(int)
X_test_prep = model.prepare_x(X_test)

predictions = model.predict(X_test_prep)
accuracy = np.mean(predictions == y_test)
print(f"\nTest Accuracy: {accuracy:.4f}")

# Get learning curve
costs = model.learning_curve(X_train_prep, y_train)
print(f"Initial cost: {costs[0]:.6f}")
print(f"Final cost: {costs[-1]:.6f}")
print(f"Total iterations: {len(costs) - 1}")
# Out:
# Iteration 0: Cost = 0.805995, Weight change = 0.07130213
# Iteration 1: Cost = 0.761959, Weight change = 0.06732655
# Iteration 2: Cost = 0.722835, Weight change = 0.06347602
# Iteration 3: Cost = 0.688131, Weight change = 0.05978975
# Iteration 4: Cost = 0.657360, Weight change = 0.05629839
# Iteration 5: Cost = 0.630056, Weight change = 0.05302307
# Iteration 6: Cost = 0.605788, Weight change = 0.04997514
# Iteration 7: Cost = 0.584165, Weight change = 0.04715687
# Iteration 8: Cost = 0.564840, Weight change = 0.04456302
# Iteration 9: Cost = 0.547508, Weight change = 0.04218292
# Iteration 10: Cost = 0.531908, Weight change = 0.04000249
# Iteration 11: Cost = 0.517814, Weight change = 0.03800591
# Iteration 12: Cost = 0.505031, Weight change = 0.03617696
# Iteration 13: Cost = 0.493396, Weight change = 0.03449982
# Iteration 14: Cost = 0.482768, Weight change = 0.03295957
# Iteration 15: Cost = 0.473026, Weight change = 0.03154249
# Iteration 16: Cost = 0.464067, Weight change = 0.03023612
# Iteration 17: Cost = 0.455804, Weight change = 0.02902926
# Iteration 18: Cost = 0.448158, Weight change = 0.02791192
# Iteration 19: Cost = 0.441066, Weight change = 0.02687520
# Iteration 20: Cost = 0.434469, Weight change = 0.02591120
# Iteration 21: Cost = 0.428318, Weight change = 0.02501294
# Iteration 22: Cost = 0.422570, Weight change = 0.02417418
# Iteration 23: Cost = 0.417185, Weight change = 0.02338943
# Iteration 24: Cost = 0.412132, Weight change = 0.02265378
# Iteration 25: Cost = 0.407380, Weight change = 0.02196287
# Iteration 26: Cost = 0.402903, Weight change = 0.02131282
# Iteration 27: Cost = 0.398679, Weight change = 0.02070016
# Iteration 28: Cost = 0.394685, Weight change = 0.02012178
# Iteration 29: Cost = 0.390904, Weight change = 0.01957490
# Iteration 30: Cost = 0.387320, Weight change = 0.01905702
# Iteration 31: Cost = 0.383916, Weight change = 0.01856590
# Iteration 32: Cost = 0.380680, Weight change = 0.01809949
# Iteration 33: Cost = 0.377601, Weight change = 0.01765596
# Iteration 34: Cost = 0.374665, Weight change = 0.01723366
# Iteration 35: Cost = 0.371865, Weight change = 0.01683108
# Iteration 36: Cost = 0.369190, Weight change = 0.01644685
# Iteration 37: Cost = 0.366633, Weight change = 0.01607971
# Iteration 38: Cost = 0.364186, Weight change = 0.01572854
# Iteration 39: Cost = 0.361841, Weight change = 0.01539229
# Iteration 40: Cost = 0.359594, Weight change = 0.01507000
# Iteration 41: Cost = 0.357437, Weight change = 0.01476082
# Iteration 42: Cost = 0.355366, Weight change = 0.01446392
# Iteration 43: Cost = 0.353375, Weight change = 0.01417858
# Iteration 44: Cost = 0.351460, Weight change = 0.01390411
# Iteration 45: Cost = 0.349617, Weight change = 0.01363989
# Iteration 46: Cost = 0.347842, Weight change = 0.01338534
# Iteration 47: Cost = 0.346131, Weight change = 0.01313991
# Iteration 48: Cost = 0.344481, Weight change = 0.01290312
# Iteration 49: Cost = 0.342888, Weight change = 0.01267449
# Iteration 50: Cost = 0.341351, Weight change = 0.01245360
# Iteration 51: Cost = 0.339865, Weight change = 0.01224006
# Iteration 52: Cost = 0.338429, Weight change = 0.01203348
# Iteration 53: Cost = 0.337040, Weight change = 0.01183353
# Iteration 54: Cost = 0.335696, Weight change = 0.01163987
# Iteration 55: Cost = 0.334395, Weight change = 0.01145220
# Iteration 56: Cost = 0.333135, Weight change = 0.01127025
# Iteration 57: Cost = 0.331914, Weight change = 0.01109374
# Iteration 58: Cost = 0.330730, Weight change = 0.01092242
# Iteration 59: Cost = 0.329582, Weight change = 0.01075607
# Iteration 60: Cost = 0.328468, Weight change = 0.01059446
# Iteration 61: Cost = 0.327386, Weight change = 0.01043738
# Iteration 62: Cost = 0.326336, Weight change = 0.01028465
# Iteration 63: Cost = 0.325316, Weight change = 0.01013607
# Iteration 64: Cost = 0.324325, Weight change = 0.00999147
# Iteration 65: Cost = 0.323361, Weight change = 0.00985069
# Iteration 66: Cost = 0.322424, Weight change = 0.00971358
# Iteration 67: Cost = 0.321513, Weight change = 0.00957999
# Iteration 68: Cost = 0.320626, Weight change = 0.00944978
# Iteration 69: Cost = 0.319762, Weight change = 0.00932283
# Iteration 70: Cost = 0.318922, Weight change = 0.00919899
# Iteration 71: Cost = 0.318103, Weight change = 0.00907817
# Iteration 72: Cost = 0.317305, Weight change = 0.00896025
# Iteration 73: Cost = 0.316528, Weight change = 0.00884511
# Iteration 74: Cost = 0.315770, Weight change = 0.00873267
# Iteration 75: Cost = 0.315031, Weight change = 0.00862282
# Iteration 76: Cost = 0.314311, Weight change = 0.00851547
# Iteration 77: Cost = 0.313608, Weight change = 0.00841054
# Iteration 78: Cost = 0.312922, Weight change = 0.00830794
# Iteration 79: Cost = 0.312252, Weight change = 0.00820760
# Iteration 80: Cost = 0.311598, Weight change = 0.00810943
# Iteration 81: Cost = 0.310960, Weight change = 0.00801337
# Iteration 82: Cost = 0.310336, Weight change = 0.00791935
# Iteration 83: Cost = 0.309727, Weight change = 0.00782730
# Iteration 84: Cost = 0.309132, Weight change = 0.00773716
# Iteration 85: Cost = 0.308550, Weight change = 0.00764887
# Iteration 86: Cost = 0.307982, Weight change = 0.00756237
# Iteration 87: Cost = 0.307426, Weight change = 0.00747761
# Iteration 88: Cost = 0.306882, Weight change = 0.00739453
# Iteration 89: Cost = 0.306350, Weight change = 0.00731309
# Iteration 90: Cost = 0.305830, Weight change = 0.00723322
# Iteration 91: Cost = 0.305320, Weight change = 0.00715490
# Iteration 92: Cost = 0.304822, Weight change = 0.00707806
# Iteration 93: Cost = 0.304334, Weight change = 0.00700268
# Iteration 94: Cost = 0.303857, Weight change = 0.00692871
# Iteration 95: Cost = 0.303389, Weight change = 0.00685610
# Iteration 96: Cost = 0.302931, Weight change = 0.00678482
# Iteration 97: Cost = 0.302483, Weight change = 0.00671484
# Iteration 98: Cost = 0.302043, Weight change = 0.00664611
# Iteration 99: Cost = 0.301612, Weight change = 0.00657861
# Iteration 100: Cost = 0.301190, Weight change = 0.00651230
# Iteration 101: Cost = 0.300777, Weight change = 0.00644715
# Iteration 102: Cost = 0.300371, Weight change = 0.00638313
# Iteration 103: Cost = 0.299974, Weight change = 0.00632020
# Iteration 104: Cost = 0.299584, Weight change = 0.00625835
# Iteration 105: Cost = 0.299202, Weight change = 0.00619754
# Iteration 106: Cost = 0.298827, Weight change = 0.00613775
# Iteration 107: Cost = 0.298459, Weight change = 0.00607895
# Iteration 108: Cost = 0.298098, Weight change = 0.00602111
# Iteration 109: Cost = 0.297744, Weight change = 0.00596422
# Iteration 110: Cost = 0.297397, Weight change = 0.00590825
# Iteration 111: Cost = 0.297056, Weight change = 0.00585317
# Iteration 112: Cost = 0.296721, Weight change = 0.00579898
# Iteration 113: Cost = 0.296393, Weight change = 0.00574563
# Iteration 114: Cost = 0.296070, Weight change = 0.00569312
# Iteration 115: Cost = 0.295753, Weight change = 0.00564143
# Iteration 116: Cost = 0.295442, Weight change = 0.00559053
# Iteration 117: Cost = 0.295136, Weight change = 0.00554041
# Iteration 118: Cost = 0.294836, Weight change = 0.00549106
# Iteration 119: Cost = 0.294541, Weight change = 0.00544244
# Iteration 120: Cost = 0.294252, Weight change = 0.00539455
# Iteration 121: Cost = 0.293967, Weight change = 0.00534737
# Iteration 122: Cost = 0.293687, Weight change = 0.00530089
# Iteration 123: Cost = 0.293412, Weight change = 0.00525508
# Iteration 124: Cost = 0.293142, Weight change = 0.00520994
# Iteration 125: Cost = 0.292876, Weight change = 0.00516545
# Iteration 126: Cost = 0.292615, Weight change = 0.00512159
# Iteration 127: Cost = 0.292358, Weight change = 0.00507836
# Iteration 128: Cost = 0.292106, Weight change = 0.00503573
# Iteration 129: Cost = 0.291857, Weight change = 0.00499371
# Iteration 130: Cost = 0.291613, Weight change = 0.00495226
# Iteration 131: Cost = 0.291373, Weight change = 0.00491139
# Iteration 132: Cost = 0.291137, Weight change = 0.00487108
# Iteration 133: Cost = 0.290904, Weight change = 0.00483132
# Iteration 134: Cost = 0.290675, Weight change = 0.00479210
# Iteration 135: Cost = 0.290450, Weight change = 0.00475340
# Iteration 136: Cost = 0.290229, Weight change = 0.00471522
# Iteration 137: Cost = 0.290011, Weight change = 0.00467754
# Iteration 138: Cost = 0.289796, Weight change = 0.00464036
# Iteration 139: Cost = 0.289585, Weight change = 0.00460367
# Iteration 140: Cost = 0.289378, Weight change = 0.00456746
# Iteration 141: Cost = 0.289173, Weight change = 0.00453171
# Iteration 142: Cost = 0.288972, Weight change = 0.00449642
# Iteration 143: Cost = 0.288773, Weight change = 0.00446159
# Iteration 144: Cost = 0.288578, Weight change = 0.00442719
# Iteration 145: Cost = 0.288386, Weight change = 0.00439323
# Iteration 146: Cost = 0.288196, Weight change = 0.00435969
# Iteration 147: Cost = 0.288010, Weight change = 0.00432657
# Iteration 148: Cost = 0.287826, Weight change = 0.00429387
# Iteration 149: Cost = 0.287645, Weight change = 0.00426156
# Iteration 150: Cost = 0.287467, Weight change = 0.00422965
# Iteration 151: Cost = 0.287292, Weight change = 0.00419812
# Iteration 152: Cost = 0.287119, Weight change = 0.00416698
# Iteration 153: Cost = 0.286948, Weight change = 0.00413621
# Iteration 154: Cost = 0.286780, Weight change = 0.00410581
# Iteration 155: Cost = 0.286615, Weight change = 0.00407577
# Iteration 156: Cost = 0.286452, Weight change = 0.00404609
# Iteration 157: Cost = 0.286291, Weight change = 0.00401675
# Iteration 158: Cost = 0.286132, Weight change = 0.00398776
# Iteration 159: Cost = 0.285976, Weight change = 0.00395910
# Iteration 160: Cost = 0.285822, Weight change = 0.00393077
# Iteration 161: Cost = 0.285670, Weight change = 0.00390277
# Iteration 162: Cost = 0.285521, Weight change = 0.00387509
# Iteration 163: Cost = 0.285373, Weight change = 0.00384773
# Iteration 164: Cost = 0.285228, Weight change = 0.00382067
# Iteration 165: Cost = 0.285084, Weight change = 0.00379391
# Iteration 166: Cost = 0.284943, Weight change = 0.00376746
# Iteration 167: Cost = 0.284803, Weight change = 0.00374130
# Iteration 168: Cost = 0.284666, Weight change = 0.00371543
# Iteration 169: Cost = 0.284530, Weight change = 0.00368984
# Iteration 170: Cost = 0.284396, Weight change = 0.00366454
# Iteration 171: Cost = 0.284264, Weight change = 0.00363951
# Iteration 172: Cost = 0.284134, Weight change = 0.00361475
# Iteration 173: Cost = 0.284006, Weight change = 0.00359026
# Iteration 174: Cost = 0.283879, Weight change = 0.00356603
# Iteration 175: Cost = 0.283754, Weight change = 0.00354205
# Iteration 176: Cost = 0.283630, Weight change = 0.00351834
# Iteration 177: Cost = 0.283509, Weight change = 0.00349487
# Iteration 178: Cost = 0.283389, Weight change = 0.00347165
# Iteration 179: Cost = 0.283270, Weight change = 0.00344868
# Iteration 180: Cost = 0.283153, Weight change = 0.00342594
# Iteration 181: Cost = 0.283038, Weight change = 0.00340344
# Iteration 182: Cost = 0.282924, Weight change = 0.00338117
# Iteration 183: Cost = 0.282811, Weight change = 0.00335913
# Iteration 184: Cost = 0.282700, Weight change = 0.00333731
# Iteration 185: Cost = 0.282591, Weight change = 0.00331571
# Iteration 186: Cost = 0.282482, Weight change = 0.00329434
# Iteration 187: Cost = 0.282376, Weight change = 0.00327318
# Iteration 188: Cost = 0.282270, Weight change = 0.00325223
# Iteration 189: Cost = 0.282166, Weight change = 0.00323149
# Iteration 190: Cost = 0.282063, Weight change = 0.00321096
# Iteration 191: Cost = 0.281962, Weight change = 0.00319062
# Iteration 192: Cost = 0.281862, Weight change = 0.00317049
# Iteration 193: Cost = 0.281763, Weight change = 0.00315056
# Iteration 194: Cost = 0.281665, Weight change = 0.00313082
# Iteration 195: Cost = 0.281568, Weight change = 0.00311127
# Iteration 196: Cost = 0.281473, Weight change = 0.00309191
# Iteration 197: Cost = 0.281379, Weight change = 0.00307274
# Iteration 198: Cost = 0.281286, Weight change = 0.00305375
# Iteration 199: Cost = 0.281194, Weight change = 0.00303494
# Iteration 200: Cost = 0.281104, Weight change = 0.00301631
# Iteration 201: Cost = 0.281014, Weight change = 0.00299786
# Iteration 202: Cost = 0.280925, Weight change = 0.00297958
# Iteration 203: Cost = 0.280838, Weight change = 0.00296147
# Iteration 204: Cost = 0.280752, Weight change = 0.00294353
# Iteration 205: Cost = 0.280666, Weight change = 0.00292576
# Iteration 206: Cost = 0.280582, Weight change = 0.00290815
# Iteration 207: Cost = 0.280499, Weight change = 0.00289071
# Iteration 208: Cost = 0.280416, Weight change = 0.00287342
# Iteration 209: Cost = 0.280335, Weight change = 0.00285630
# Iteration 210: Cost = 0.280255, Weight change = 0.00283932
# Iteration 211: Cost = 0.280175, Weight change = 0.00282251
# Iteration 212: Cost = 0.280097, Weight change = 0.00280584
# Iteration 213: Cost = 0.280019, Weight change = 0.00278932
# Iteration 214: Cost = 0.279942, Weight change = 0.00277296
# Iteration 215: Cost = 0.279867, Weight change = 0.00275673
# Iteration 216: Cost = 0.279792, Weight change = 0.00274066
# Iteration 217: Cost = 0.279718, Weight change = 0.00272472
# Iteration 218: Cost = 0.279645, Weight change = 0.00270893
# Iteration 219: Cost = 0.279572, Weight change = 0.00269327
# Iteration 220: Cost = 0.279501, Weight change = 0.00267775
# Iteration 221: Cost = 0.279430, Weight change = 0.00266237
# Iteration 222: Cost = 0.279360, Weight change = 0.00264711
# Iteration 223: Cost = 0.279291, Weight change = 0.00263200
# Iteration 224: Cost = 0.279223, Weight change = 0.00261701
# Iteration 225: Cost = 0.279155, Weight change = 0.00260215
# Iteration 226: Cost = 0.279089, Weight change = 0.00258741
# Iteration 227: Cost = 0.279023, Weight change = 0.00257281
# Iteration 228: Cost = 0.278957, Weight change = 0.00255832
# Iteration 229: Cost = 0.278893, Weight change = 0.00254396
# Iteration 230: Cost = 0.278829, Weight change = 0.00252972
# Iteration 231: Cost = 0.278766, Weight change = 0.00251560
# Iteration 232: Cost = 0.278703, Weight change = 0.00250160
# Iteration 233: Cost = 0.278642, Weight change = 0.00248771
# Iteration 234: Cost = 0.278581, Weight change = 0.00247394
# Iteration 235: Cost = 0.278520, Weight change = 0.00246028
# Iteration 236: Cost = 0.278461, Weight change = 0.00244674
# Iteration 237: Cost = 0.278402, Weight change = 0.00243330
# Iteration 238: Cost = 0.278343, Weight change = 0.00241998
# Iteration 239: Cost = 0.278285, Weight change = 0.00240676
# Iteration 240: Cost = 0.278228, Weight change = 0.00239365
# Iteration 241: Cost = 0.278172, Weight change = 0.00238065
# Iteration 242: Cost = 0.278116, Weight change = 0.00236776
# Iteration 243: Cost = 0.278061, Weight change = 0.00235496
# Iteration 244: Cost = 0.278006, Weight change = 0.00234227
# Iteration 245: Cost = 0.277952, Weight change = 0.00232968
# Iteration 246: Cost = 0.277898, Weight change = 0.00231719
# Iteration 247: Cost = 0.277845, Weight change = 0.00230480
# Iteration 248: Cost = 0.277793, Weight change = 0.00229251
# Iteration 249: Cost = 0.277741, Weight change = 0.00228031
# Iteration 250: Cost = 0.277690, Weight change = 0.00226821
# Iteration 251: Cost = 0.277639, Weight change = 0.00225621
# Iteration 252: Cost = 0.277589, Weight change = 0.00224430
# Iteration 253: Cost = 0.277539, Weight change = 0.00223248
# Iteration 254: Cost = 0.277490, Weight change = 0.00222075
# Iteration 255: Cost = 0.277441, Weight change = 0.00220911
# Iteration 256: Cost = 0.277393, Weight change = 0.00219756
# Iteration 257: Cost = 0.277345, Weight change = 0.00218610
# Iteration 258: Cost = 0.277298, Weight change = 0.00217473
# Iteration 259: Cost = 0.277251, Weight change = 0.00216345
# Iteration 260: Cost = 0.277205, Weight change = 0.00215225
# Iteration 261: Cost = 0.277159, Weight change = 0.00214113
# Iteration 262: Cost = 0.277114, Weight change = 0.00213010
# Iteration 263: Cost = 0.277069, Weight change = 0.00211915
# Iteration 264: Cost = 0.277025, Weight change = 0.00210829
# Iteration 265: Cost = 0.276981, Weight change = 0.00209750
# Iteration 266: Cost = 0.276938, Weight change = 0.00208680
# Iteration 267: Cost = 0.276895, Weight change = 0.00207617
# Iteration 268: Cost = 0.276852, Weight change = 0.00206563
# Iteration 269: Cost = 0.276810, Weight change = 0.00205516
# Iteration 270: Cost = 0.276768, Weight change = 0.00204477
# Iteration 271: Cost = 0.276727, Weight change = 0.00203445
# Iteration 272: Cost = 0.276686, Weight change = 0.00202421
# Iteration 273: Cost = 0.276646, Weight change = 0.00201405
# Iteration 274: Cost = 0.276606, Weight change = 0.00200396
# Iteration 275: Cost = 0.276566, Weight change = 0.00199394
# Iteration 276: Cost = 0.276527, Weight change = 0.00198399
# Iteration 277: Cost = 0.276488, Weight change = 0.00197412
# Iteration 278: Cost = 0.276449, Weight change = 0.00196432
# Iteration 279: Cost = 0.276411, Weight change = 0.00195458
# Iteration 280: Cost = 0.276373, Weight change = 0.00194492
# Iteration 281: Cost = 0.276336, Weight change = 0.00193533
# Iteration 282: Cost = 0.276299, Weight change = 0.00192580
# Iteration 283: Cost = 0.276262, Weight change = 0.00191634
# Iteration 284: Cost = 0.276226, Weight change = 0.00190695
# Iteration 285: Cost = 0.276190, Weight change = 0.00189762
# Iteration 286: Cost = 0.276155, Weight change = 0.00188836
# Iteration 287: Cost = 0.276119, Weight change = 0.00187917
# Iteration 288: Cost = 0.276085, Weight change = 0.00187004
# Iteration 289: Cost = 0.276050, Weight change = 0.00186097
# Iteration 290: Cost = 0.276016, Weight change = 0.00185196
# Iteration 291: Cost = 0.275982, Weight change = 0.00184302
# Iteration 292: Cost = 0.275948, Weight change = 0.00183414
# Iteration 293: Cost = 0.275915, Weight change = 0.00182532
# Iteration 294: Cost = 0.275882, Weight change = 0.00181656
# Iteration 295: Cost = 0.275850, Weight change = 0.00180786
# Iteration 296: Cost = 0.275817, Weight change = 0.00179922
# Iteration 297: Cost = 0.275785, Weight change = 0.00179064
# Iteration 298: Cost = 0.275754, Weight change = 0.00178211
# Iteration 299: Cost = 0.275722, Weight change = 0.00177365
# Iteration 300: Cost = 0.275691, Weight change = 0.00176524
# Iteration 301: Cost = 0.275660, Weight change = 0.00175689
# Iteration 302: Cost = 0.275630, Weight change = 0.00174859
# Iteration 303: Cost = 0.275600, Weight change = 0.00174035
# Iteration 304: Cost = 0.275570, Weight change = 0.00173217
# Iteration 305: Cost = 0.275540, Weight change = 0.00172404
# Iteration 306: Cost = 0.275511, Weight change = 0.00171596
# Iteration 307: Cost = 0.275482, Weight change = 0.00170794
# Iteration 308: Cost = 0.275453, Weight change = 0.00169997
# Iteration 309: Cost = 0.275424, Weight change = 0.00169205
# Iteration 310: Cost = 0.275396, Weight change = 0.00168419
# Iteration 311: Cost = 0.275368, Weight change = 0.00167637
# Iteration 312: Cost = 0.275340, Weight change = 0.00166861
# Iteration 313: Cost = 0.275313, Weight change = 0.00166090
# Iteration 314: Cost = 0.275285, Weight change = 0.00165323
# Iteration 315: Cost = 0.275258, Weight change = 0.00164562
# Iteration 316: Cost = 0.275232, Weight change = 0.00163806
# Iteration 317: Cost = 0.275205, Weight change = 0.00163055
# Iteration 318: Cost = 0.275179, Weight change = 0.00162308
# Iteration 319: Cost = 0.275153, Weight change = 0.00161566
# Iteration 320: Cost = 0.275127, Weight change = 0.00160829
# Iteration 321: Cost = 0.275101, Weight change = 0.00160097
# Iteration 322: Cost = 0.275076, Weight change = 0.00159369
# Iteration 323: Cost = 0.275051, Weight change = 0.00158646
# Iteration 324: Cost = 0.275026, Weight change = 0.00157928
# Iteration 325: Cost = 0.275001, Weight change = 0.00157214
# Iteration 326: Cost = 0.274977, Weight change = 0.00156505
# Iteration 327: Cost = 0.274953, Weight change = 0.00155800
# Iteration 328: Cost = 0.274929, Weight change = 0.00155099
# Iteration 329: Cost = 0.274905, Weight change = 0.00154403
# Iteration 330: Cost = 0.274881, Weight change = 0.00153712
# Iteration 331: Cost = 0.274858, Weight change = 0.00153024
# Iteration 332: Cost = 0.274835, Weight change = 0.00152341
# Iteration 333: Cost = 0.274812, Weight change = 0.00151662
# Iteration 334: Cost = 0.274789, Weight change = 0.00150988
# Iteration 335: Cost = 0.274766, Weight change = 0.00150317
# Iteration 336: Cost = 0.274744, Weight change = 0.00149651
# Iteration 337: Cost = 0.274722, Weight change = 0.00148988
# Iteration 338: Cost = 0.274700, Weight change = 0.00148330
# Iteration 339: Cost = 0.274678, Weight change = 0.00147676
# Iteration 340: Cost = 0.274657, Weight change = 0.00147026
# Iteration 341: Cost = 0.274635, Weight change = 0.00146380
# Iteration 342: Cost = 0.274614, Weight change = 0.00145738
# Iteration 343: Cost = 0.274593, Weight change = 0.00145099
# Iteration 344: Cost = 0.274572, Weight change = 0.00144465
# Iteration 345: Cost = 0.274552, Weight change = 0.00143834
# Iteration 346: Cost = 0.274531, Weight change = 0.00143207
# Iteration 347: Cost = 0.274511, Weight change = 0.00142584
# Iteration 348: Cost = 0.274491, Weight change = 0.00141965
# Iteration 349: Cost = 0.274471, Weight change = 0.00141349
# Iteration 350: Cost = 0.274451, Weight change = 0.00140737
# Iteration 351: Cost = 0.274432, Weight change = 0.00140129
# Iteration 352: Cost = 0.274412, Weight change = 0.00139524
# Iteration 353: Cost = 0.274393, Weight change = 0.00138923
# Iteration 354: Cost = 0.274374, Weight change = 0.00138325
# Iteration 355: Cost = 0.274355, Weight change = 0.00137731
# Iteration 356: Cost = 0.274336, Weight change = 0.00137141
# Iteration 357: Cost = 0.274317, Weight change = 0.00136554
# Iteration 358: Cost = 0.274299, Weight change = 0.00135970
# Iteration 359: Cost = 0.274281, Weight change = 0.00135390
# Iteration 360: Cost = 0.274263, Weight change = 0.00134813
# Iteration 361: Cost = 0.274245, Weight change = 0.00134240
# Iteration 362: Cost = 0.274227, Weight change = 0.00133670
# Iteration 363: Cost = 0.274209, Weight change = 0.00133103
# Iteration 364: Cost = 0.274192, Weight change = 0.00132539
# Iteration 365: Cost = 0.274174, Weight change = 0.00131979
# Iteration 366: Cost = 0.274157, Weight change = 0.00131422
# Iteration 367: Cost = 0.274140, Weight change = 0.00130868
# Iteration 368: Cost = 0.274123, Weight change = 0.00130318
# Iteration 369: Cost = 0.274106, Weight change = 0.00129770
# Iteration 370: Cost = 0.274089, Weight change = 0.00129226
# Iteration 371: Cost = 0.274073, Weight change = 0.00128685
# Iteration 372: Cost = 0.274057, Weight change = 0.00128147
# Iteration 373: Cost = 0.274040, Weight change = 0.00127611
# Iteration 374: Cost = 0.274024, Weight change = 0.00127079
# Iteration 375: Cost = 0.274008, Weight change = 0.00126550
# Iteration 376: Cost = 0.273992, Weight change = 0.00126024
# Iteration 377: Cost = 0.273977, Weight change = 0.00125501
# Iteration 378: Cost = 0.273961, Weight change = 0.00124981
# Iteration 379: Cost = 0.273946, Weight change = 0.00124464
# Iteration 380: Cost = 0.273930, Weight change = 0.00123950
# Iteration 381: Cost = 0.273915, Weight change = 0.00123438
# Iteration 382: Cost = 0.273900, Weight change = 0.00122930
# Iteration 383: Cost = 0.273885, Weight change = 0.00122424
# Iteration 384: Cost = 0.273870, Weight change = 0.00121921
# Iteration 385: Cost = 0.273855, Weight change = 0.00121421
# Iteration 386: Cost = 0.273841, Weight change = 0.00120924
# Iteration 387: Cost = 0.273826, Weight change = 0.00120429
# Iteration 388: Cost = 0.273812, Weight change = 0.00119937
# Iteration 389: Cost = 0.273798, Weight change = 0.00119448
# Iteration 390: Cost = 0.273784, Weight change = 0.00118962
# Iteration 391: Cost = 0.273770, Weight change = 0.00118478
# Iteration 392: Cost = 0.273756, Weight change = 0.00117997
# Iteration 393: Cost = 0.273742, Weight change = 0.00117518
# Iteration 394: Cost = 0.273728, Weight change = 0.00117042
# Iteration 395: Cost = 0.273715, Weight change = 0.00116569
# Iteration 396: Cost = 0.273701, Weight change = 0.00116098
# Iteration 397: Cost = 0.273688, Weight change = 0.00115630
# Iteration 398: Cost = 0.273675, Weight change = 0.00115164
# Iteration 399: Cost = 0.273662, Weight change = 0.00114701
# Iteration 400: Cost = 0.273649, Weight change = 0.00114241
# Iteration 401: Cost = 0.273636, Weight change = 0.00113783
# Iteration 402: Cost = 0.273623, Weight change = 0.00113327
# Iteration 403: Cost = 0.273610, Weight change = 0.00112874
# Iteration 404: Cost = 0.273597, Weight change = 0.00112423
# Iteration 405: Cost = 0.273585, Weight change = 0.00111974
# Iteration 406: Cost = 0.273573, Weight change = 0.00111528
# Iteration 407: Cost = 0.273560, Weight change = 0.00111085
# Iteration 408: Cost = 0.273548, Weight change = 0.00110644
# Iteration 409: Cost = 0.273536, Weight change = 0.00110205
# Iteration 410: Cost = 0.273524, Weight change = 0.00109768
# Iteration 411: Cost = 0.273512, Weight change = 0.00109334
# Iteration 412: Cost = 0.273500, Weight change = 0.00108902
# Iteration 413: Cost = 0.273488, Weight change = 0.00108472
# Iteration 414: Cost = 0.273477, Weight change = 0.00108044
# Iteration 415: Cost = 0.273465, Weight change = 0.00107619
# Iteration 416: Cost = 0.273454, Weight change = 0.00107196
# Iteration 417: Cost = 0.273442, Weight change = 0.00106775
# Iteration 418: Cost = 0.273431, Weight change = 0.00106357
# Iteration 419: Cost = 0.273420, Weight change = 0.00105941
# Iteration 420: Cost = 0.273409, Weight change = 0.00105526
# Iteration 421: Cost = 0.273398, Weight change = 0.00105114
# Iteration 422: Cost = 0.273387, Weight change = 0.00104704
# Iteration 423: Cost = 0.273376, Weight change = 0.00104296
# Iteration 424: Cost = 0.273365, Weight change = 0.00103891
# Iteration 425: Cost = 0.273354, Weight change = 0.00103487
# Iteration 426: Cost = 0.273344, Weight change = 0.00103086
# Iteration 427: Cost = 0.273333, Weight change = 0.00102686
# Iteration 428: Cost = 0.273323, Weight change = 0.00102289
# Iteration 429: Cost = 0.273312, Weight change = 0.00101893
# Iteration 430: Cost = 0.273302, Weight change = 0.00101500
# Iteration 431: Cost = 0.273292, Weight change = 0.00101109
# Iteration 432: Cost = 0.273282, Weight change = 0.00100719
# Iteration 433: Cost = 0.273272, Weight change = 0.00100332
# Iteration 434: Cost = 0.273262, Weight change = 0.00099946
# Iteration 435: Cost = 0.273252, Weight change = 0.00099563
# Iteration 436: Cost = 0.273242, Weight change = 0.00099181
# Iteration 437: Cost = 0.273232, Weight change = 0.00098802
# Iteration 438: Cost = 0.273223, Weight change = 0.00098424
# Iteration 439: Cost = 0.273213, Weight change = 0.00098048
# Iteration 440: Cost = 0.273204, Weight change = 0.00097674
# Iteration 441: Cost = 0.273194, Weight change = 0.00097302
# Iteration 442: Cost = 0.273185, Weight change = 0.00096932
# Iteration 443: Cost = 0.273175, Weight change = 0.00096564
# Iteration 444: Cost = 0.273166, Weight change = 0.00096198
# Iteration 445: Cost = 0.273157, Weight change = 0.00095833
# Iteration 446: Cost = 0.273148, Weight change = 0.00095470
# Iteration 447: Cost = 0.273139, Weight change = 0.00095109
# Iteration 448: Cost = 0.273130, Weight change = 0.00094750
# Iteration 449: Cost = 0.273121, Weight change = 0.00094393
# Iteration 450: Cost = 0.273112, Weight change = 0.00094037
# Iteration 451: Cost = 0.273103, Weight change = 0.00093683
# Iteration 452: Cost = 0.273095, Weight change = 0.00093331
# Iteration 453: Cost = 0.273086, Weight change = 0.00092980
# Iteration 454: Cost = 0.273078, Weight change = 0.00092632
# Iteration 455: Cost = 0.273069, Weight change = 0.00092285
# Iteration 456: Cost = 0.273061, Weight change = 0.00091939
# Iteration 457: Cost = 0.273052, Weight change = 0.00091596
# Iteration 458: Cost = 0.273044, Weight change = 0.00091254
# Iteration 459: Cost = 0.273036, Weight change = 0.00090914
# Iteration 460: Cost = 0.273028, Weight change = 0.00090575
# Iteration 461: Cost = 0.273019, Weight change = 0.00090238
# Iteration 462: Cost = 0.273011, Weight change = 0.00089903
# Iteration 463: Cost = 0.273003, Weight change = 0.00089569
# Iteration 464: Cost = 0.272995, Weight change = 0.00089237
# Iteration 465: Cost = 0.272988, Weight change = 0.00088907
# Iteration 466: Cost = 0.272980, Weight change = 0.00088578
# Iteration 467: Cost = 0.272972, Weight change = 0.00088250
# Iteration 468: Cost = 0.272964, Weight change = 0.00087925
# Iteration 469: Cost = 0.272957, Weight change = 0.00087601
# Iteration 470: Cost = 0.272949, Weight change = 0.00087278
# Iteration 471: Cost = 0.272941, Weight change = 0.00086957
# Iteration 472: Cost = 0.272934, Weight change = 0.00086637
# Iteration 473: Cost = 0.272926, Weight change = 0.00086320
# Iteration 474: Cost = 0.272919, Weight change = 0.00086003
# Iteration 475: Cost = 0.272912, Weight change = 0.00085688
# Iteration 476: Cost = 0.272904, Weight change = 0.00085375
# Iteration 477: Cost = 0.272897, Weight change = 0.00085063
# Iteration 478: Cost = 0.272890, Weight change = 0.00084752
# Iteration 479: Cost = 0.272883, Weight change = 0.00084443
# Iteration 480: Cost = 0.272876, Weight change = 0.00084136
# Iteration 481: Cost = 0.272869, Weight change = 0.00083829
# Iteration 482: Cost = 0.272862, Weight change = 0.00083525
# Iteration 483: Cost = 0.272855, Weight change = 0.00083222
# Iteration 484: Cost = 0.272848, Weight change = 0.00082920
# Iteration 485: Cost = 0.272841, Weight change = 0.00082619
# Iteration 486: Cost = 0.272835, Weight change = 0.00082320
# Iteration 487: Cost = 0.272828, Weight change = 0.00082023
# Iteration 488: Cost = 0.272821, Weight change = 0.00081727
# Iteration 489: Cost = 0.272815, Weight change = 0.00081432
# Iteration 490: Cost = 0.272808, Weight change = 0.00081138
# Iteration 491: Cost = 0.272801, Weight change = 0.00080846
# Iteration 492: Cost = 0.272795, Weight change = 0.00080555
# Iteration 493: Cost = 0.272789, Weight change = 0.00080266
# Iteration 494: Cost = 0.272782, Weight change = 0.00079978
# Iteration 495: Cost = 0.272776, Weight change = 0.00079691
# Iteration 496: Cost = 0.272770, Weight change = 0.00079406
# Iteration 497: Cost = 0.272763, Weight change = 0.00079122
# Iteration 498: Cost = 0.272757, Weight change = 0.00078839
# Iteration 499: Cost = 0.272751, Weight change = 0.00078558
# Iteration 500: Cost = 0.272745, Weight change = 0.00078278
# Iteration 501: Cost = 0.272739, Weight change = 0.00077999
# Iteration 502: Cost = 0.272733, Weight change = 0.00077721
# Iteration 503: Cost = 0.272727, Weight change = 0.00077445
# Iteration 504: Cost = 0.272721, Weight change = 0.00077170
# Iteration 505: Cost = 0.272715, Weight change = 0.00076896
# Iteration 506: Cost = 0.272709, Weight change = 0.00076623
# Iteration 507: Cost = 0.272703, Weight change = 0.00076352
# Iteration 508: Cost = 0.272697, Weight change = 0.00076082
# Iteration 509: Cost = 0.272692, Weight change = 0.00075813
# Iteration 510: Cost = 0.272686, Weight change = 0.00075545
# Iteration 511: Cost = 0.272680, Weight change = 0.00075279
# Iteration 512: Cost = 0.272675, Weight change = 0.00075014
# Iteration 513: Cost = 0.272669, Weight change = 0.00074750
# Iteration 514: Cost = 0.272664, Weight change = 0.00074487
# Iteration 515: Cost = 0.272658, Weight change = 0.00074225
# Iteration 516: Cost = 0.272653, Weight change = 0.00073965
# Iteration 517: Cost = 0.272647, Weight change = 0.00073705
# Iteration 518: Cost = 0.272642, Weight change = 0.00073447
# Iteration 519: Cost = 0.272636, Weight change = 0.00073190
# Iteration 520: Cost = 0.272631, Weight change = 0.00072934
# Iteration 521: Cost = 0.272626, Weight change = 0.00072679
# Iteration 522: Cost = 0.272621, Weight change = 0.00072426
# Iteration 523: Cost = 0.272615, Weight change = 0.00072173
# Iteration 524: Cost = 0.272610, Weight change = 0.00071922
# Iteration 525: Cost = 0.272605, Weight change = 0.00071672
# Iteration 526: Cost = 0.272600, Weight change = 0.00071423
# Iteration 527: Cost = 0.272595, Weight change = 0.00071175
# Iteration 528: Cost = 0.272590, Weight change = 0.00070928
# Iteration 529: Cost = 0.272585, Weight change = 0.00070682
# Iteration 530: Cost = 0.272580, Weight change = 0.00070437
# Iteration 531: Cost = 0.272575, Weight change = 0.00070194
# Iteration 532: Cost = 0.272570, Weight change = 0.00069951
# Iteration 533: Cost = 0.272565, Weight change = 0.00069709
# Iteration 534: Cost = 0.272561, Weight change = 0.00069469
# Iteration 535: Cost = 0.272556, Weight change = 0.00069230
# Iteration 536: Cost = 0.272551, Weight change = 0.00068991
# Iteration 537: Cost = 0.272546, Weight change = 0.00068754
# Iteration 538: Cost = 0.272542, Weight change = 0.00068518
# Iteration 539: Cost = 0.272537, Weight change = 0.00068282
# Iteration 540: Cost = 0.272532, Weight change = 0.00068048
# Iteration 541: Cost = 0.272528, Weight change = 0.00067815
# Iteration 542: Cost = 0.272523, Weight change = 0.00067583
# Iteration 543: Cost = 0.272519, Weight change = 0.00067352
# Iteration 544: Cost = 0.272514, Weight change = 0.00067121
# Iteration 545: Cost = 0.272510, Weight change = 0.00066892
# Iteration 546: Cost = 0.272505, Weight change = 0.00066664
# Iteration 547: Cost = 0.272501, Weight change = 0.00066437
# Iteration 548: Cost = 0.272496, Weight change = 0.00066210
# Iteration 549: Cost = 0.272492, Weight change = 0.00065985
# Iteration 550: Cost = 0.272488, Weight change = 0.00065761
# Iteration 551: Cost = 0.272484, Weight change = 0.00065538
# Iteration 552: Cost = 0.272479, Weight change = 0.00065315
# Iteration 553: Cost = 0.272475, Weight change = 0.00065094
# Iteration 554: Cost = 0.272471, Weight change = 0.00064873
# Iteration 555: Cost = 0.272467, Weight change = 0.00064654
# Iteration 556: Cost = 0.272463, Weight change = 0.00064435
# Iteration 557: Cost = 0.272458, Weight change = 0.00064217
# Iteration 558: Cost = 0.272454, Weight change = 0.00064001
# Iteration 559: Cost = 0.272450, Weight change = 0.00063785
# Iteration 560: Cost = 0.272446, Weight change = 0.00063570
# Iteration 561: Cost = 0.272442, Weight change = 0.00063356
# Iteration 562: Cost = 0.272438, Weight change = 0.00063143
# Iteration 563: Cost = 0.272434, Weight change = 0.00062931
# Iteration 564: Cost = 0.272430, Weight change = 0.00062719
# Iteration 565: Cost = 0.272426, Weight change = 0.00062509
# Iteration 566: Cost = 0.272423, Weight change = 0.00062300
# Iteration 567: Cost = 0.272419, Weight change = 0.00062091
# Iteration 568: Cost = 0.272415, Weight change = 0.00061883
# Iteration 569: Cost = 0.272411, Weight change = 0.00061676
# Iteration 570: Cost = 0.272407, Weight change = 0.00061470
# Iteration 571: Cost = 0.272404, Weight change = 0.00061265
# Iteration 572: Cost = 0.272400, Weight change = 0.00061061
# Iteration 573: Cost = 0.272396, Weight change = 0.00060857
# Iteration 574: Cost = 0.272392, Weight change = 0.00060655
# Iteration 575: Cost = 0.272389, Weight change = 0.00060453
# Iteration 576: Cost = 0.272385, Weight change = 0.00060252
# Iteration 577: Cost = 0.272382, Weight change = 0.00060052
# Iteration 578: Cost = 0.272378, Weight change = 0.00059853
# Iteration 579: Cost = 0.272374, Weight change = 0.00059655
# Iteration 580: Cost = 0.272371, Weight change = 0.00059457
# Iteration 581: Cost = 0.272367, Weight change = 0.00059260
# Iteration 582: Cost = 0.272364, Weight change = 0.00059064
# Iteration 583: Cost = 0.272361, Weight change = 0.00058869
# Iteration 584: Cost = 0.272357, Weight change = 0.00058675
# Iteration 585: Cost = 0.272354, Weight change = 0.00058481
# Iteration 586: Cost = 0.272350, Weight change = 0.00058289
# Iteration 587: Cost = 0.272347, Weight change = 0.00058097
# Iteration 588: Cost = 0.272344, Weight change = 0.00057905
# Iteration 589: Cost = 0.272340, Weight change = 0.00057715
# Iteration 590: Cost = 0.272337, Weight change = 0.00057525
# Iteration 591: Cost = 0.272334, Weight change = 0.00057337
# Iteration 592: Cost = 0.272330, Weight change = 0.00057149
# Iteration 593: Cost = 0.272327, Weight change = 0.00056961
# Iteration 594: Cost = 0.272324, Weight change = 0.00056775
# Iteration 595: Cost = 0.272321, Weight change = 0.00056589
# Iteration 596: Cost = 0.272318, Weight change = 0.00056404
# Iteration 597: Cost = 0.272314, Weight change = 0.00056220
# Iteration 598: Cost = 0.272311, Weight change = 0.00056036
# Iteration 599: Cost = 0.272308, Weight change = 0.00055854
# Iteration 600: Cost = 0.272305, Weight change = 0.00055672
# Iteration 601: Cost = 0.272302, Weight change = 0.00055490
# Iteration 602: Cost = 0.272299, Weight change = 0.00055310
# Iteration 603: Cost = 0.272296, Weight change = 0.00055130
# Iteration 604: Cost = 0.272293, Weight change = 0.00054951
# Iteration 605: Cost = 0.272290, Weight change = 0.00054773
# Iteration 606: Cost = 0.272287, Weight change = 0.00054595
# Iteration 607: Cost = 0.272284, Weight change = 0.00054418
# Iteration 608: Cost = 0.272281, Weight change = 0.00054242
# Iteration 609: Cost = 0.272278, Weight change = 0.00054066
# Iteration 610: Cost = 0.272275, Weight change = 0.00053892
# Iteration 611: Cost = 0.272272, Weight change = 0.00053718
# Iteration 612: Cost = 0.272269, Weight change = 0.00053544
# Iteration 613: Cost = 0.272267, Weight change = 0.00053371
# Iteration 614: Cost = 0.272264, Weight change = 0.00053199
# Iteration 615: Cost = 0.272261, Weight change = 0.00053028
# Iteration 616: Cost = 0.272258, Weight change = 0.00052857
# Iteration 617: Cost = 0.272255, Weight change = 0.00052687
# Iteration 618: Cost = 0.272253, Weight change = 0.00052518
# Iteration 619: Cost = 0.272250, Weight change = 0.00052350
# Iteration 620: Cost = 0.272247, Weight change = 0.00052182
# Iteration 621: Cost = 0.272244, Weight change = 0.00052014
# Iteration 622: Cost = 0.272242, Weight change = 0.00051848
# Iteration 623: Cost = 0.272239, Weight change = 0.00051682
# Iteration 624: Cost = 0.272236, Weight change = 0.00051516
# Iteration 625: Cost = 0.272234, Weight change = 0.00051352
# Iteration 626: Cost = 0.272231, Weight change = 0.00051188
# Iteration 627: Cost = 0.272229, Weight change = 0.00051024
# Iteration 628: Cost = 0.272226, Weight change = 0.00050862
# Iteration 629: Cost = 0.272223, Weight change = 0.00050700
# Iteration 630: Cost = 0.272221, Weight change = 0.00050538
# Iteration 631: Cost = 0.272218, Weight change = 0.00050377
# Iteration 632: Cost = 0.272216, Weight change = 0.00050217
# Iteration 633: Cost = 0.272213, Weight change = 0.00050058
# Iteration 634: Cost = 0.272211, Weight change = 0.00049899
# Iteration 635: Cost = 0.272208, Weight change = 0.00049740
# Iteration 636: Cost = 0.272206, Weight change = 0.00049583
# Iteration 637: Cost = 0.272204, Weight change = 0.00049426
# Iteration 638: Cost = 0.272201, Weight change = 0.00049269
# Iteration 639: Cost = 0.272199, Weight change = 0.00049113
# Iteration 640: Cost = 0.272196, Weight change = 0.00048958
# Iteration 641: Cost = 0.272194, Weight change = 0.00048803
# Iteration 642: Cost = 0.272192, Weight change = 0.00048649
# Iteration 643: Cost = 0.272189, Weight change = 0.00048496
# Iteration 644: Cost = 0.272187, Weight change = 0.00048343
# Iteration 645: Cost = 0.272185, Weight change = 0.00048191
# Iteration 646: Cost = 0.272182, Weight change = 0.00048039
# Iteration 647: Cost = 0.272180, Weight change = 0.00047888
# Iteration 648: Cost = 0.272178, Weight change = 0.00047737
# Iteration 649: Cost = 0.272175, Weight change = 0.00047587
# Iteration 650: Cost = 0.272173, Weight change = 0.00047438
# Iteration 651: Cost = 0.272171, Weight change = 0.00047289
# Iteration 652: Cost = 0.272169, Weight change = 0.00047141
# Iteration 653: Cost = 0.272167, Weight change = 0.00046993
# Iteration 654: Cost = 0.272164, Weight change = 0.00046846
# Iteration 655: Cost = 0.272162, Weight change = 0.00046700
# Iteration 656: Cost = 0.272160, Weight change = 0.00046554
# Iteration 657: Cost = 0.272158, Weight change = 0.00046409
# Iteration 658: Cost = 0.272156, Weight change = 0.00046264
# Iteration 659: Cost = 0.272154, Weight change = 0.00046119
# Iteration 660: Cost = 0.272151, Weight change = 0.00045976
# Iteration 661: Cost = 0.272149, Weight change = 0.00045832
# Iteration 662: Cost = 0.272147, Weight change = 0.00045690
# Iteration 663: Cost = 0.272145, Weight change = 0.00045548
# Iteration 664: Cost = 0.272143, Weight change = 0.00045406
# Iteration 665: Cost = 0.272141, Weight change = 0.00045265
# Iteration 666: Cost = 0.272139, Weight change = 0.00045125
# Iteration 667: Cost = 0.272137, Weight change = 0.00044985
# Iteration 668: Cost = 0.272135, Weight change = 0.00044845
# Iteration 669: Cost = 0.272133, Weight change = 0.00044706
# Iteration 670: Cost = 0.272131, Weight change = 0.00044568
# Iteration 671: Cost = 0.272129, Weight change = 0.00044430
# Iteration 672: Cost = 0.272127, Weight change = 0.00044293
# Iteration 673: Cost = 0.272125, Weight change = 0.00044156
# Iteration 674: Cost = 0.272123, Weight change = 0.00044020
# Iteration 675: Cost = 0.272121, Weight change = 0.00043884
# Iteration 676: Cost = 0.272119, Weight change = 0.00043748
# Iteration 677: Cost = 0.272118, Weight change = 0.00043614
# Iteration 678: Cost = 0.272116, Weight change = 0.00043479
# Iteration 679: Cost = 0.272114, Weight change = 0.00043346
# Iteration 680: Cost = 0.272112, Weight change = 0.00043212
# Iteration 681: Cost = 0.272110, Weight change = 0.00043079
# Iteration 682: Cost = 0.272108, Weight change = 0.00042947
# Iteration 683: Cost = 0.272106, Weight change = 0.00042815
# Iteration 684: Cost = 0.272105, Weight change = 0.00042684
# Iteration 685: Cost = 0.272103, Weight change = 0.00042553
# Iteration 686: Cost = 0.272101, Weight change = 0.00042423
# Iteration 687: Cost = 0.272099, Weight change = 0.00042293
# Iteration 688: Cost = 0.272097, Weight change = 0.00042164
# Iteration 689: Cost = 0.272096, Weight change = 0.00042035
# Iteration 690: Cost = 0.272094, Weight change = 0.00041906
# Iteration 691: Cost = 0.272092, Weight change = 0.00041778
# Iteration 692: Cost = 0.272090, Weight change = 0.00041651
# Iteration 693: Cost = 0.272089, Weight change = 0.00041524
# Iteration 694: Cost = 0.272087, Weight change = 0.00041397
# Iteration 695: Cost = 0.272085, Weight change = 0.00041271
# Iteration 696: Cost = 0.272084, Weight change = 0.00041146
# Iteration 697: Cost = 0.272082, Weight change = 0.00041021
# Iteration 698: Cost = 0.272080, Weight change = 0.00040896
# Iteration 699: Cost = 0.272079, Weight change = 0.00040772
# Iteration 700: Cost = 0.272077, Weight change = 0.00040648
# Iteration 701: Cost = 0.272075, Weight change = 0.00040525
# Iteration 702: Cost = 0.272074, Weight change = 0.00040402
# Iteration 703: Cost = 0.272072, Weight change = 0.00040279
# Iteration 704: Cost = 0.272070, Weight change = 0.00040157
# Iteration 705: Cost = 0.272069, Weight change = 0.00040036
# Iteration 706: Cost = 0.272067, Weight change = 0.00039915
# Iteration 707: Cost = 0.272066, Weight change = 0.00039794
# Iteration 708: Cost = 0.272064, Weight change = 0.00039674
# Iteration 709: Cost = 0.272063, Weight change = 0.00039554
# Iteration 710: Cost = 0.272061, Weight change = 0.00039435
# Iteration 711: Cost = 0.272059, Weight change = 0.00039316
# Iteration 712: Cost = 0.272058, Weight change = 0.00039198
# Iteration 713: Cost = 0.272056, Weight change = 0.00039080
# Iteration 714: Cost = 0.272055, Weight change = 0.00038962
# Iteration 715: Cost = 0.272053, Weight change = 0.00038845
# Iteration 716: Cost = 0.272052, Weight change = 0.00038728
# Iteration 717: Cost = 0.272050, Weight change = 0.00038612
# Iteration 718: Cost = 0.272049, Weight change = 0.00038496
# Iteration 719: Cost = 0.272047, Weight change = 0.00038380
# Iteration 720: Cost = 0.272046, Weight change = 0.00038265
# Iteration 721: Cost = 0.272044, Weight change = 0.00038151
# Iteration 722: Cost = 0.272043, Weight change = 0.00038036
# Iteration 723: Cost = 0.272042, Weight change = 0.00037922
# Iteration 724: Cost = 0.272040, Weight change = 0.00037809
# Iteration 725: Cost = 0.272039, Weight change = 0.00037696
# Iteration 726: Cost = 0.272037, Weight change = 0.00037583
# Iteration 727: Cost = 0.272036, Weight change = 0.00037471
# Iteration 728: Cost = 0.272035, Weight change = 0.00037359
# Iteration 729: Cost = 0.272033, Weight change = 0.00037248
# Iteration 730: Cost = 0.272032, Weight change = 0.00037137
# Iteration 731: Cost = 0.272030, Weight change = 0.00037026
# Iteration 732: Cost = 0.272029, Weight change = 0.00036916
# Iteration 733: Cost = 0.272028, Weight change = 0.00036806
# Iteration 734: Cost = 0.272026, Weight change = 0.00036697
# Iteration 735: Cost = 0.272025, Weight change = 0.00036588
# Iteration 736: Cost = 0.272024, Weight change = 0.00036479
# Iteration 737: Cost = 0.272022, Weight change = 0.00036371
# Iteration 738: Cost = 0.272021, Weight change = 0.00036263
# Iteration 739: Cost = 0.272020, Weight change = 0.00036155
# Iteration 740: Cost = 0.272018, Weight change = 0.00036048
# Iteration 741: Cost = 0.272017, Weight change = 0.00035941
# Iteration 742: Cost = 0.272016, Weight change = 0.00035835
# Iteration 743: Cost = 0.272015, Weight change = 0.00035729
# Iteration 744: Cost = 0.272013, Weight change = 0.00035623
# Iteration 745: Cost = 0.272012, Weight change = 0.00035518
# Iteration 746: Cost = 0.272011, Weight change = 0.00035413
# Iteration 747: Cost = 0.272010, Weight change = 0.00035309
# Iteration 748: Cost = 0.272008, Weight change = 0.00035205
# Iteration 749: Cost = 0.272007, Weight change = 0.00035101
# Iteration 750: Cost = 0.272006, Weight change = 0.00034997
# Iteration 751: Cost = 0.272005, Weight change = 0.00034894
# Iteration 752: Cost = 0.272003, Weight change = 0.00034792
# Iteration 753: Cost = 0.272002, Weight change = 0.00034689
# Iteration 754: Cost = 0.272001, Weight change = 0.00034587
# Iteration 755: Cost = 0.272000, Weight change = 0.00034486
# Iteration 756: Cost = 0.271999, Weight change = 0.00034384
# Iteration 757: Cost = 0.271998, Weight change = 0.00034284
# Iteration 758: Cost = 0.271996, Weight change = 0.00034183
# Iteration 759: Cost = 0.271995, Weight change = 0.00034083
# Iteration 760: Cost = 0.271994, Weight change = 0.00033983
# Iteration 761: Cost = 0.271993, Weight change = 0.00033883
# Iteration 762: Cost = 0.271992, Weight change = 0.00033784
# Iteration 763: Cost = 0.271991, Weight change = 0.00033685
# Iteration 764: Cost = 0.271990, Weight change = 0.00033587
# Iteration 765: Cost = 0.271988, Weight change = 0.00033489
# Iteration 766: Cost = 0.271987, Weight change = 0.00033391
# Iteration 767: Cost = 0.271986, Weight change = 0.00033294
# Iteration 768: Cost = 0.271985, Weight change = 0.00033196
# Iteration 769: Cost = 0.271984, Weight change = 0.00033100
# Iteration 770: Cost = 0.271983, Weight change = 0.00033003
# Iteration 771: Cost = 0.271982, Weight change = 0.00032907
# Iteration 772: Cost = 0.271981, Weight change = 0.00032811
# Iteration 773: Cost = 0.271980, Weight change = 0.00032716
# Iteration 774: Cost = 0.271979, Weight change = 0.00032621
# Iteration 775: Cost = 0.271978, Weight change = 0.00032526
# Iteration 776: Cost = 0.271977, Weight change = 0.00032431
# Iteration 777: Cost = 0.271975, Weight change = 0.00032337
# Iteration 778: Cost = 0.271974, Weight change = 0.00032243
# Iteration 779: Cost = 0.271973, Weight change = 0.00032150
# Iteration 780: Cost = 0.271972, Weight change = 0.00032057
# Iteration 781: Cost = 0.271971, Weight change = 0.00031964
# Iteration 782: Cost = 0.271970, Weight change = 0.00031871
# Iteration 783: Cost = 0.271969, Weight change = 0.00031779
# Iteration 784: Cost = 0.271968, Weight change = 0.00031687
# Iteration 785: Cost = 0.271967, Weight change = 0.00031595
# Iteration 786: Cost = 0.271966, Weight change = 0.00031504
# Iteration 787: Cost = 0.271965, Weight change = 0.00031413
# Iteration 788: Cost = 0.271964, Weight change = 0.00031322
# Iteration 789: Cost = 0.271963, Weight change = 0.00031232
# Iteration 790: Cost = 0.271962, Weight change = 0.00031142
# Iteration 791: Cost = 0.271961, Weight change = 0.00031052
# Iteration 792: Cost = 0.271961, Weight change = 0.00030963
# Iteration 793: Cost = 0.271960, Weight change = 0.00030874
# Iteration 794: Cost = 0.271959, Weight change = 0.00030785
# Iteration 795: Cost = 0.271958, Weight change = 0.00030696
# Iteration 796: Cost = 0.271957, Weight change = 0.00030608
# Iteration 797: Cost = 0.271956, Weight change = 0.00030520
# Iteration 798: Cost = 0.271955, Weight change = 0.00030432
# Iteration 799: Cost = 0.271954, Weight change = 0.00030345
# Iteration 800: Cost = 0.271953, Weight change = 0.00030258
# Iteration 801: Cost = 0.271952, Weight change = 0.00030171
# Iteration 802: Cost = 0.271951, Weight change = 0.00030085
# Iteration 803: Cost = 0.271950, Weight change = 0.00029999
# Iteration 804: Cost = 0.271949, Weight change = 0.00029913
# Iteration 805: Cost = 0.271949, Weight change = 0.00029827
# Iteration 806: Cost = 0.271948, Weight change = 0.00029742
# Iteration 807: Cost = 0.271947, Weight change = 0.00029657
# Iteration 808: Cost = 0.271946, Weight change = 0.00029572
# Iteration 809: Cost = 0.271945, Weight change = 0.00029488
# Iteration 810: Cost = 0.271944, Weight change = 0.00029403
# Iteration 811: Cost = 0.271943, Weight change = 0.00029319
# Iteration 812: Cost = 0.271942, Weight change = 0.00029236
# Iteration 813: Cost = 0.271942, Weight change = 0.00029152
# Iteration 814: Cost = 0.271941, Weight change = 0.00029069
# ...
# Iteration 2898: Cost = 0.271784, Weight change = 0.00000185
# Iteration 2899: Cost = 0.271784, Weight change = 0.00000184
# Iteration 2900: Cost = 0.271784, Weight change = 0.00000184
# Iteration 2901: Cost = 0.271784, Weight change = 0.00000183
# Iteration 2902: Cost = 0.271784, Weight change = 0.00000183
# Iteration 2903: Cost = 0.271784, Weight change = 0.00000183
# Iteration 2904: Cost = 0.271784, Weight change = 0.00000182
# Iteration 2905: Cost = 0.271784, Weight change = 0.00000182
# Iteration 2906: Cost = 0.271784, Weight change = 0.00000181
# Iteration 2907: Cost = 0.271784, Weight change = 0.00000181
# Iteration 2908: Cost = 0.271784, Weight change = 0.00000181
# Iteration 2909: Cost = 0.271784, Weight change = 0.00000180
# Iteration 2910: Cost = 0.271784, Weight change = 0.00000180
# Iteration 2911: Cost = 0.271784, Weight change = 0.00000179
# Iteration 2912: Cost = 0.271784, Weight change = 0.00000179
# Iteration 2913: Cost = 0.271784, Weight change = 0.00000178
# Iteration 2914: Cost = 0.271784, Weight change = 0.00000178
# Iteration 2915: Cost = 0.271784, Weight change = 0.00000178
# Iteration 2916: Cost = 0.271784, Weight change = 0.00000177
# Iteration 2917: Cost = 0.271784, Weight change = 0.00000177
# Iteration 2918: Cost = 0.271784, Weight change = 0.00000176
# Iteration 2919: Cost = 0.271784, Weight change = 0.00000176
# Iteration 2920: Cost = 0.271784, Weight change = 0.00000176
# Iteration 2921: Cost = 0.271784, Weight change = 0.00000175
# Iteration 2922: Cost = 0.271784, Weight change = 0.00000175
# Iteration 2923: Cost = 0.271784, Weight change = 0.00000174
# Iteration 2924: Cost = 0.271784, Weight change = 0.00000174
# Iteration 2925: Cost = 0.271784, Weight change = 0.00000173
# Iteration 2926: Cost = 0.271784, Weight change = 0.00000173
# Iteration 2927: Cost = 0.271784, Weight change = 0.00000173
# Iteration 2928: Cost = 0.271784, Weight change = 0.00000172
# Iteration 2929: Cost = 0.271784, Weight change = 0.00000172
# Iteration 2930: Cost = 0.271784, Weight change = 0.00000171
# Iteration 2931: Cost = 0.271784, Weight change = 0.00000171
# Iteration 2932: Cost = 0.271784, Weight change = 0.00000171
# Iteration 2933: Cost = 0.271784, Weight change = 0.00000170
# Iteration 2934: Cost = 0.271784, Weight change = 0.00000170
# Iteration 2935: Cost = 0.271784, Weight change = 0.00000169
# Iteration 2936: Cost = 0.271784, Weight change = 0.00000169
# Iteration 2937: Cost = 0.271784, Weight change = 0.00000169
# Iteration 2938: Cost = 0.271784, Weight change = 0.00000168
# Iteration 2939: Cost = 0.271784, Weight change = 0.00000168
# Iteration 2940: Cost = 0.271784, Weight change = 0.00000168
# Iteration 2941: Cost = 0.271784, Weight change = 0.00000167
# Iteration 2942: Cost = 0.271784, Weight change = 0.00000167
# Iteration 2943: Cost = 0.271784, Weight change = 0.00000166
# Iteration 2944: Cost = 0.271784, Weight change = 0.00000166
# Iteration 2945: Cost = 0.271784, Weight change = 0.00000166
# Iteration 2946: Cost = 0.271784, Weight change = 0.00000165
# Iteration 2947: Cost = 0.271784, Weight change = 0.00000165
# Iteration 2948: Cost = 0.271784, Weight change = 0.00000164
# Iteration 2949: Cost = 0.271784, Weight change = 0.00000164
# Iteration 2950: Cost = 0.271784, Weight change = 0.00000164
# Iteration 2951: Cost = 0.271784, Weight change = 0.00000163
# Iteration 2952: Cost = 0.271784, Weight change = 0.00000163
# Iteration 2953: Cost = 0.271784, Weight change = 0.00000162
# Iteration 2954: Cost = 0.271784, Weight change = 0.00000162
# Iteration 2955: Cost = 0.271784, Weight change = 0.00000162
# Iteration 2956: Cost = 0.271784, Weight change = 0.00000161
# Iteration 2957: Cost = 0.271784, Weight change = 0.00000161
# Iteration 2958: Cost = 0.271784, Weight change = 0.00000161
# Iteration 2959: Cost = 0.271784, Weight change = 0.00000160
# Iteration 2960: Cost = 0.271784, Weight change = 0.00000160
# Iteration 2961: Cost = 0.271784, Weight change = 0.00000159
# Iteration 2962: Cost = 0.271784, Weight change = 0.00000159
# Iteration 2963: Cost = 0.271784, Weight change = 0.00000159
# Iteration 2964: Cost = 0.271784, Weight change = 0.00000158
# Iteration 2965: Cost = 0.271784, Weight change = 0.00000158
# Iteration 2966: Cost = 0.271784, Weight change = 0.00000158
# Iteration 2967: Cost = 0.271784, Weight change = 0.00000157
# Iteration 2968: Cost = 0.271784, Weight change = 0.00000157
# Iteration 2969: Cost = 0.271784, Weight change = 0.00000157
# Iteration 2970: Cost = 0.271784, Weight change = 0.00000156
# Iteration 2971: Cost = 0.271784, Weight change = 0.00000156
# Iteration 2972: Cost = 0.271784, Weight change = 0.00000155
# Iteration 2973: Cost = 0.271784, Weight change = 0.00000155
# Iteration 2974: Cost = 0.271784, Weight change = 0.00000155
# Iteration 2975: Cost = 0.271784, Weight change = 0.00000154
# Iteration 2976: Cost = 0.271784, Weight change = 0.00000154
# Iteration 2977: Cost = 0.271784, Weight change = 0.00000154
# Iteration 2978: Cost = 0.271784, Weight change = 0.00000153
# Iteration 2979: Cost = 0.271784, Weight change = 0.00000153
# Iteration 2980: Cost = 0.271784, Weight change = 0.00000153
# Iteration 2981: Cost = 0.271784, Weight change = 0.00000152
# Iteration 2982: Cost = 0.271784, Weight change = 0.00000152
# Iteration 2983: Cost = 0.271784, Weight change = 0.00000151
# Iteration 2984: Cost = 0.271784, Weight change = 0.00000151
# Iteration 2985: Cost = 0.271784, Weight change = 0.00000151
# Iteration 2986: Cost = 0.271784, Weight change = 0.00000150
# Iteration 2987: Cost = 0.271784, Weight change = 0.00000150
# Iteration 2988: Cost = 0.271784, Weight change = 0.00000150
# Iteration 2989: Cost = 0.271784, Weight change = 0.00000149
# Iteration 2990: Cost = 0.271784, Weight change = 0.00000149
# Iteration 2991: Cost = 0.271784, Weight change = 0.00000149
# Iteration 2992: Cost = 0.271784, Weight change = 0.00000148
# Iteration 2993: Cost = 0.271784, Weight change = 0.00000148
# Iteration 2994: Cost = 0.271784, Weight change = 0.00000148
# Iteration 2995: Cost = 0.271784, Weight change = 0.00000147
# Iteration 2996: Cost = 0.271784, Weight change = 0.00000147
# Iteration 2997: Cost = 0.271784, Weight change = 0.00000147
# Iteration 2998: Cost = 0.271784, Weight change = 0.00000146
# Iteration 2999: Cost = 0.271784, Weight change = 0.00000146
# Iteration 3000: Cost = 0.271784, Weight change = 0.00000146
# Iteration 3001: Cost = 0.271784, Weight change = 0.00000145
# Iteration 3002: Cost = 0.271784, Weight change = 0.00000145
# Iteration 3003: Cost = 0.271784, Weight change = 0.00000145
# Iteration 3004: Cost = 0.271784, Weight change = 0.00000144
# Iteration 3005: Cost = 0.271784, Weight change = 0.00000144
# Iteration 3006: Cost = 0.271784, Weight change = 0.00000144
# Iteration 3007: Cost = 0.271784, Weight change = 0.00000143
# Iteration 3008: Cost = 0.271784, Weight change = 0.00000143
# Iteration 3009: Cost = 0.271784, Weight change = 0.00000143
# Iteration 3010: Cost = 0.271784, Weight change = 0.00000142
# Iteration 3011: Cost = 0.271784, Weight change = 0.00000142
# Iteration 3012: Cost = 0.271784, Weight change = 0.00000142
# Iteration 3013: Cost = 0.271784, Weight change = 0.00000141
# Iteration 3014: Cost = 0.271784, Weight change = 0.00000141
# Iteration 3015: Cost = 0.271784, Weight change = 0.00000141
# Iteration 3016: Cost = 0.271784, Weight change = 0.00000140
# Iteration 3017: Cost = 0.271784, Weight change = 0.00000140
# Iteration 3018: Cost = 0.271784, Weight change = 0.00000140
# Iteration 3019: Cost = 0.271784, Weight change = 0.00000139
# Iteration 3020: Cost = 0.271784, Weight change = 0.00000139
# Iteration 3021: Cost = 0.271784, Weight change = 0.00000139
# Iteration 3022: Cost = 0.271784, Weight change = 0.00000138
# Iteration 3023: Cost = 0.271784, Weight change = 0.00000138
# Iteration 3024: Cost = 0.271784, Weight change = 0.00000138
# Iteration 3025: Cost = 0.271784, Weight change = 0.00000137
# Iteration 3026: Cost = 0.271784, Weight change = 0.00000137
# Iteration 3027: Cost = 0.271784, Weight change = 0.00000137
# Iteration 3028: Cost = 0.271784, Weight change = 0.00000136
# Iteration 3029: Cost = 0.271784, Weight change = 0.00000136
# Iteration 3030: Cost = 0.271784, Weight change = 0.00000136
# Iteration 3031: Cost = 0.271784, Weight change = 0.00000135
# Iteration 3032: Cost = 0.271784, Weight change = 0.00000135
# Iteration 3033: Cost = 0.271784, Weight change = 0.00000135
# Iteration 3034: Cost = 0.271784, Weight change = 0.00000134
# Iteration 3035: Cost = 0.271784, Weight change = 0.00000134
# Iteration 3036: Cost = 0.271784, Weight change = 0.00000134
# Iteration 3037: Cost = 0.271784, Weight change = 0.00000134
# Iteration 3038: Cost = 0.271784, Weight change = 0.00000133
# Iteration 3039: Cost = 0.271784, Weight change = 0.00000133
# Iteration 3040: Cost = 0.271784, Weight change = 0.00000133
# Iteration 3041: Cost = 0.271784, Weight change = 0.00000132
# Iteration 3042: Cost = 0.271784, Weight change = 0.00000132
# Iteration 3043: Cost = 0.271784, Weight change = 0.00000132
# Iteration 3044: Cost = 0.271784, Weight change = 0.00000131
# Iteration 3045: Cost = 0.271784, Weight change = 0.00000131
# Iteration 3046: Cost = 0.271784, Weight change = 0.00000131
# Iteration 3047: Cost = 0.271784, Weight change = 0.00000130
# Iteration 3048: Cost = 0.271784, Weight change = 0.00000130
# Iteration 3049: Cost = 0.271784, Weight change = 0.00000130
# Iteration 3050: Cost = 0.271784, Weight change = 0.00000130
# Iteration 3051: Cost = 0.271784, Weight change = 0.00000129
# Iteration 3052: Cost = 0.271784, Weight change = 0.00000129
# Iteration 3053: Cost = 0.271784, Weight change = 0.00000129
# Iteration 3054: Cost = 0.271784, Weight change = 0.00000128
# Iteration 3055: Cost = 0.271784, Weight change = 0.00000128
# Iteration 3056: Cost = 0.271784, Weight change = 0.00000128
# Iteration 3057: Cost = 0.271784, Weight change = 0.00000127
# Iteration 3058: Cost = 0.271784, Weight change = 0.00000127
# Iteration 3059: Cost = 0.271784, Weight change = 0.00000127
# Iteration 3060: Cost = 0.271784, Weight change = 0.00000127
# Iteration 3061: Cost = 0.271784, Weight change = 0.00000126
# Iteration 3062: Cost = 0.271784, Weight change = 0.00000126
# Iteration 3063: Cost = 0.271784, Weight change = 0.00000126
# Iteration 3064: Cost = 0.271784, Weight change = 0.00000125
# Iteration 3065: Cost = 0.271784, Weight change = 0.00000125
# Iteration 3066: Cost = 0.271784, Weight change = 0.00000125
# Iteration 3067: Cost = 0.271784, Weight change = 0.00000125
# Iteration 3068: Cost = 0.271784, Weight change = 0.00000124
# Iteration 3069: Cost = 0.271784, Weight change = 0.00000124
# Iteration 3070: Cost = 0.271784, Weight change = 0.00000124
# Iteration 3071: Cost = 0.271784, Weight change = 0.00000123
# Iteration 3072: Cost = 0.271784, Weight change = 0.00000123
# Iteration 3073: Cost = 0.271784, Weight change = 0.00000123
# Iteration 3074: Cost = 0.271784, Weight change = 0.00000122
# Iteration 3075: Cost = 0.271784, Weight change = 0.00000122
# Iteration 3076: Cost = 0.271784, Weight change = 0.00000122
# Iteration 3077: Cost = 0.271784, Weight change = 0.00000122
# Iteration 3078: Cost = 0.271784, Weight change = 0.00000121
# Iteration 3079: Cost = 0.271784, Weight change = 0.00000121
# Iteration 3080: Cost = 0.271784, Weight change = 0.00000121
# Iteration 3081: Cost = 0.271784, Weight change = 0.00000121
# Iteration 3082: Cost = 0.271784, Weight change = 0.00000120
# Iteration 3083: Cost = 0.271784, Weight change = 0.00000120
# Iteration 3084: Cost = 0.271784, Weight change = 0.00000120
# Iteration 3085: Cost = 0.271784, Weight change = 0.00000119
# Iteration 3086: Cost = 0.271784, Weight change = 0.00000119
# Iteration 3087: Cost = 0.271784, Weight change = 0.00000119
# Iteration 3088: Cost = 0.271784, Weight change = 0.00000119
# Iteration 3089: Cost = 0.271784, Weight change = 0.00000118
# Iteration 3090: Cost = 0.271784, Weight change = 0.00000118
# Iteration 3091: Cost = 0.271784, Weight change = 0.00000118
# Iteration 3092: Cost = 0.271784, Weight change = 0.00000117
# Iteration 3093: Cost = 0.271784, Weight change = 0.00000117
# Iteration 3094: Cost = 0.271784, Weight change = 0.00000117
# Iteration 3095: Cost = 0.271784, Weight change = 0.00000117
# Iteration 3096: Cost = 0.271784, Weight change = 0.00000116
# Iteration 3097: Cost = 0.271784, Weight change = 0.00000116
# Iteration 3098: Cost = 0.271784, Weight change = 0.00000116
# Iteration 3099: Cost = 0.271784, Weight change = 0.00000116
# Iteration 3100: Cost = 0.271784, Weight change = 0.00000115
# Iteration 3101: Cost = 0.271784, Weight change = 0.00000115
# Iteration 3102: Cost = 0.271784, Weight change = 0.00000115
# Iteration 3103: Cost = 0.271784, Weight change = 0.00000114
# Iteration 3104: Cost = 0.271784, Weight change = 0.00000114
# Iteration 3105: Cost = 0.271784, Weight change = 0.00000114
# Iteration 3106: Cost = 0.271784, Weight change = 0.00000114
# Iteration 3107: Cost = 0.271784, Weight change = 0.00000113
# Iteration 3108: Cost = 0.271784, Weight change = 0.00000113
# Iteration 3109: Cost = 0.271784, Weight change = 0.00000113
# Iteration 3110: Cost = 0.271784, Weight change = 0.00000113
# Iteration 3111: Cost = 0.271784, Weight change = 0.00000112
# Iteration 3112: Cost = 0.271784, Weight change = 0.00000112
# Iteration 3113: Cost = 0.271784, Weight change = 0.00000112
# Iteration 3114: Cost = 0.271784, Weight change = 0.00000112
# Iteration 3115: Cost = 0.271784, Weight change = 0.00000111
# Iteration 3116: Cost = 0.271784, Weight change = 0.00000111
# Iteration 3117: Cost = 0.271784, Weight change = 0.00000111
# Iteration 3118: Cost = 0.271784, Weight change = 0.00000111
# Iteration 3119: Cost = 0.271784, Weight change = 0.00000110
# Iteration 3120: Cost = 0.271784, Weight change = 0.00000110
# Iteration 3121: Cost = 0.271784, Weight change = 0.00000110
# Iteration 3122: Cost = 0.271784, Weight change = 0.00000109
# Iteration 3123: Cost = 0.271784, Weight change = 0.00000109
# Iteration 3124: Cost = 0.271784, Weight change = 0.00000109
# Iteration 3125: Cost = 0.271784, Weight change = 0.00000109
# Iteration 3126: Cost = 0.271784, Weight change = 0.00000108
# Iteration 3127: Cost = 0.271784, Weight change = 0.00000108
# Iteration 3128: Cost = 0.271784, Weight change = 0.00000108
# Iteration 3129: Cost = 0.271784, Weight change = 0.00000108
# Iteration 3130: Cost = 0.271784, Weight change = 0.00000107
# Iteration 3131: Cost = 0.271784, Weight change = 0.00000107
# Iteration 3132: Cost = 0.271784, Weight change = 0.00000107
# Iteration 3133: Cost = 0.271784, Weight change = 0.00000107
# Iteration 3134: Cost = 0.271784, Weight change = 0.00000106
# Iteration 3135: Cost = 0.271784, Weight change = 0.00000106
# Iteration 3136: Cost = 0.271784, Weight change = 0.00000106
# Iteration 3137: Cost = 0.271784, Weight change = 0.00000106
# Iteration 3138: Cost = 0.271784, Weight change = 0.00000105
# Iteration 3139: Cost = 0.271784, Weight change = 0.00000105
# Iteration 3140: Cost = 0.271784, Weight change = 0.00000105
# Iteration 3141: Cost = 0.271784, Weight change = 0.00000105
# Iteration 3142: Cost = 0.271784, Weight change = 0.00000104
# Iteration 3143: Cost = 0.271784, Weight change = 0.00000104
# Iteration 3144: Cost = 0.271784, Weight change = 0.00000104
# Iteration 3145: Cost = 0.271784, Weight change = 0.00000104
# Iteration 3146: Cost = 0.271784, Weight change = 0.00000104
# Iteration 3147: Cost = 0.271784, Weight change = 0.00000103
# Iteration 3148: Cost = 0.271784, Weight change = 0.00000103
# Iteration 3149: Cost = 0.271784, Weight change = 0.00000103
# Iteration 3150: Cost = 0.271784, Weight change = 0.00000103
# Iteration 3151: Cost = 0.271784, Weight change = 0.00000102
# Iteration 3152: Cost = 0.271784, Weight change = 0.00000102
# Iteration 3153: Cost = 0.271784, Weight change = 0.00000102
# Iteration 3154: Cost = 0.271784, Weight change = 0.00000102
# Iteration 3155: Cost = 0.271784, Weight change = 0.00000101
# Iteration 3156: Cost = 0.271784, Weight change = 0.00000101
# Iteration 3157: Cost = 0.271784, Weight change = 0.00000101
# Iteration 3158: Cost = 0.271784, Weight change = 0.00000101
# Iteration 3159: Cost = 0.271784, Weight change = 0.00000100
# Iteration 3160: Cost = 0.271784, Weight change = 0.00000100
# Iteration 3161: Cost = 0.271784, Weight change = 0.00000100
# Converged at iteration 3161
#
# Test Accuracy: 0.1667
# Initial cost: 0.855424
# Final cost: 0.271784
# Total iterations: 3162

# %%
# Learning rates to test
lrs = [1e-2, 1e-4, 1e-6]

# Create figure for plotting
plt.figure(figsize=(14, 8))

# Dictionary to store results
results = {}

# Train model for each learning rate
for lr in lrs:
    print(f"Training with learning rate: {lr}")
    # Create new model instance
    model = Logistic_regression()

    # Prep data with bias term
    X_train_prep = model.prepare_x(X_train)
    X_test_prep = model.prepare_x(X_test)

    # Initialize weights randomly between 0 and 1
    np.random.seed(42)  # For reproducibility across runs
    w_init = np.random.rand(X_train_prep.shape[1])

    # Fit the model
    model.fit(X_train_prep, y_train, w_init, lr=lr)

    # Get learning curves
    train_costs = model.learning_curve(X_train_prep, y_train)
    test_costs = model.learning_curve(X_test_prep, y_test)

    # Store results
    results[lr] = {
        'train_costs': train_costs,
        'test_costs': test_costs,
        'iterations': len(train_costs)
    }

    print(f"Converged after {len(train_costs)-1} iterations")
    print(f"Final training cost: {train_costs[-1]:.6f}")
    print(f"Final test cost: {test_costs[-1]:.6f}")

    # Plot training curve
    plt.plot(range(len(train_costs)), train_costs,
             label=f'Train (lr={lr})', linewidth=2, linestyle='-')

    # Plot test curve
    plt.plot(range(len(test_costs)), test_costs,
             label=f'Test (lr={lr})', linewidth=2, linestyle='--')

# Customize plot
plt.xlabel('Iteration', fontsize=12)
plt.ylabel('Average Cost', fontsize=12)
plt.title('Learning Curves: Training and Test Cost vs Iteration\nfor Different Learning Rates',
          fontsize=14, fontweight='bold')
plt.legend(loc='best', fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Optional: Use log scale for x-axis if curves converge quickly
# plt.xscale('log')

plt.show()

# Print summary comparison
print(f"\n{'='*60}")
print("SUMMARY COMPARISON")
print(f"{'='*60}")
print(f"{'Learning Rate':<15} {'Iterations':<12} {'Final Train Cost':<18} {'Final Test Cost':<18}")
print(f"{'-'*60}")
for lr in lr:
    iterations = results[lr]['iterations'] - 1
    final_train = results[lr]['train_costs'][-1]
    final_test = results[lr]['test_costs'][-1]
    print(f"{lr:<15.0e} {iterations:<12} {final_train:<18.6f} {final_test:<18.6f}")
# Out:
# Training with learning rate: 0.01
# Converged after 5000 iterations
# Final training cost: 0.272863
# Final test cost: 1.893913
# Training with learning rate: 0.0001
# Converged after 5000 iterations
# Final training cost: 1.231647
# Final test cost: 0.538727
# Training with learning rate: 1e-06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-482254209.py in <cell line: 0>()
#      26
#      27     # Get learning curves
# ---> 28     train_costs = model.learning_curve(X_train_prep, y_train)
#      29     test_costs = model.learning_curve(X_test_prep, y_test)
#      30
#
# /tmp/ipython-input-3792240616.py in learning_curve(self, X, y)
#     118         # If X and y provided, compute costs from saved weights (original slow method)
#     119         if X is not None and y is not None:
# --> 120             return [self.cost(X, y, w) for w in self.saved_w]
#     121
#     122         # Otherwise return pre-computed costs (fast method)
#
# /tmp/ipython-input-3792240616.py in cost(self, X, y, w)
#      28         y_pred = np.clip(y_pred, epsilon, 1 - epsilon)
#      29
# ---> 30         return (-np.mean(y*np.log(y_pred) + (1-y)*np.log(1-y_pred)))
#      31         # this is the coded version of the gradient descent cost function from lecture.
#      32         # y hat is the prediction, i.e. the sigmoid function.
#
# KeyboardInterrupt:

# %% [markdown]
# ### III. Evaluate your model performance through cross validation
#
# **(c)** Test the performance of your trained classifier using K-folds cross validation resampling technique. The scikit-learn package [StratifiedKFolds](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold.html#sklearn.model_selection.StratifiedKFold) may be helpful.
# - Train your logistic regression model and a K-Nearest Neighbor classification model with $k=7$ nearest neighbors.
# - Using the trained models, make two plots corresponding to each model (logistic regression and KNN): one with the training data, and one for the test data. On each plot, include the decision boundary resulting from your trained classifier.
# - Produce a Receiver Operating Characteristic curve (ROC curve) that represents the performance from cross validated performance evaluation for each classifier (your logistic regression model and the KNN model, with $k=7$ nearest neighbors). For the cross validation, use $k=10$ folds.
#   - Plot these curves on the same set of axes to compare them
#   - On the ROC curve plot, also include the chance diagonal for reference (this represents the performance of the worst possible classifier). This is represented as a line from $(0,0)$ to $(1,1)$.
#   - Calculate the Area Under the Curve for each model and include this measure in the legend of the ROC plot.
# - Comment on the following:
#   - What is the purpose of using cross validation for this problem?
#   - How do the models compare in terms of performance (both ROC curves and decision boundaries) and which model (logistic regression or KNN) would you select to use on previously unseen data for this problem and why?

# %% [markdown]
# **ANSWER**

# %% [markdown]
# # 2
#
# ## Digits classification
# **[30 points]**
#
# *An exploration of regularization, imbalanced classes, ROC and PR curves*
#
# The goal of this exercise is to apply your supervised learning skills on a very different dataset: in this case, image data; MNIST: a collection of images of handwritten digits. Your goal is to train a classifier that is able to distinguish the number "3" from all possible numbers and to do so as accurately as possible. You will first explore your data (this should always be your starting point to gain domain knowledge about the problem.). Since the feature space in this problem is 784-dimensional, overfitting is possible. To avoid overfitting you will investigate the impact of regularization on generalization performance (test accuracy) and compare regularized and unregularized logistic regression model test error against other classification techniques such as linear discriminant analysis and random forests and draw conclusions about the best-performing model.
#
# Start by loading your dataset from the [MNIST dataset](http://yann.lecun.com/exdb/mnist/) of handwritten digits, using the code provided below. MNIST has a training set of 60,000 examples, and a test set of 10,000 examples. The digits have been size-normalized and centered in a fixed-size image.
#
# Your goal is to classify whether or not an example digit is a 3. Your binary classifier should predict $y=1$ if the digit is a 3, and $y=0$ otherwise. Create your dataset by transforming your labels into a binary format (3's are class 1, and all other digits are class 0).
#
# **(a)** Plot 10 examples of each class (i.e. class $y=0$, which are not 3's and class $y=1$ which are 3's), from the training dataset.
# - Note that the data are composed of samples of length 784. These represent 28 x 28 images, but have been reshaped for storage convenience. To plot digit examples, you'll need to reshape the data to be 28 x 28 (which can be done with numpy `reshape`).
#
# **(b)** How many examples are present in each class? Show a plot of samples by class (bar plot). What fraction of samples are positive? What issues might this cause?
#
# **(c)** Using a logistic regression classifier, apply lasso regularization and retrain the model and evaluate its performance over a range of values on the regularization coefficient. You can implement this using the [LogisticRegression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) module and activating the 'l1' penalty; the parameter $C$ is the inverse of the regularization strength. Vary the value of C logarithmically from $10^{-4}$ to $10^4$ (and make your x-axes logarithmic in scale) and evaluate it at 20 different values of C. As you vary the regularization coefficient, Plot
# - The number of model parameters that are estimated to be nonzero (in the logistic regression model, one attribute is `coef_`, which gives you access to the model parameters for a trained model)
# - The cross entropy loss (which can be evaluated with the Scikit Learn `log_loss` function)
# - Area under the ROC curve (AUC)
# - The $F_1$-score (assuming a threshold of 0.5 on the predicted confidence scores, that is, scores above 0.5 are predicted as Class 1, otherwise Class 0). Scikit Learn also has a `f1_score` function which may be useful.
# - Which value of C seems best for this problem? Please select the closest power of 10. You will use this in the next part of this exercise.
#
# **(d)** Train and test a (1) logistic regression classifier with minimal regularization (using the Scikit Learn package, set penalty='l1', C=1e100 to approximate this), (2) a logistic regression classifier with the best value of the regularization parameter from the last section, (3) and a third classifier of your choosing.  This last classifier can be any classifier you want (even if we haven't yet covered it in class).
# - Compare your classifiers' performance using ROC and Precision Recall (PR) curves.
# - Plot the line that represents randomly guessing the class (50% of the time a "3", 50% not a "3"). You SHOULD NOT actually create random guesses. Instead you should think through the theory behind how ROC and PR curves work and plot the appropriate lines. It's a good practice to include these in ROC and PR curve plots as a reference point.
# - For PR curves, an excellent resource on how to correctly plot them can be found [here](https://classeval.wordpress.com/introduction/introduction-to-the-precision-recall-plot/) (ignore the section on "non-linear interpolation between two points"). This describes how a random classifier is represented in PR curves and demonstrates that it should provide a lower bound on performance.
# - When training your logistic regression model, it's recommended that you use solver="liblinear"; otherwise your results may not converge
# - Describe the performance of the classifiers you compared. Did the regularization of the logistic regression model make much difference here? Which classifier you would select for application to unseen data.

# %%
# Load the MNIST Data
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pickle

# Set this to True to download the data for the first time and False after the first time
#   so that you just load the data locally instead
download_data = True

if download_data:
    # Load data from https://www.openml.org/d/554
    X, y = fetch_openml('mnist_784', return_X_y=True, as_frame=False)

    # Adjust the labels to be '1' if y==3, and '0' otherwise
    y[y!='3'] = 0
    y[y=='3'] = 1
    y = y.astype('int')

    # Divide the data intro a training and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/7, random_state=88)

    file = open('tmpdata', 'wb')
    pickle.dump((X_train, X_test, y_train, y_test), file)
    file.close()
else:
    file = open('tmpdata', 'rb')
    X_train, X_test, y_train, y_test = pickle.load(file)
    file.close()

# %% [markdown]
# **ANSWER**
