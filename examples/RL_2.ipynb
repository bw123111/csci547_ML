# %% [markdown]
# <a href="https://colab.research.google.com/github/lucywowen/csci547_ML/blob/main/examples/RL_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Q-Learning - Lunar Lander
#
# In this assignment, you will train an agent to land a lunar lander safely on a landing pad on the surface of the moon.
#
#
# # Outline
# - [ 1 - Import Packages <img align="Right" src="./images/lunar_lander.gif" width = 60% >](#1)
# - [ 2 - Hyperparameters](#2)
# - [ 3 - The Lunar Lander Environment](#3)
#   - [ 3.1 Action Space](#3.1)
#   - [ 3.2 Observation Space](#3.2)
#   - [ 3.3 Rewards](#3.3)
#   - [ 3.4 Episode Termination](#3.4)
# - [ 4 - Load the Environment](#4)
# - [ 5 - Interacting with the Gym Environment](#5)
#     - [ 5.1 Exploring the Environment's Dynamics](#5.1)
# - [ 6 - Deep Q-Learning](#6)
#   - [ 6.1 Target Network](#6.1)
#     - [ Exercise 1](#ex01)
#   - [ 6.2 Experience Replay](#6.2)
# - [ 7 - Deep Q-Learning Algorithm with Experience Replay](#7)
#   - [ Exercise 2](#ex02)
# - [ 8 - Update the Network Weights](#8)
# - [ 9 - Train the Agent](#9)
# - [ 10 - See the Trained Agent In Action](#10)
# - [ 11 - Congratulations!](#11)
# - [ 12 - References](#12)

# %% [markdown]
# <a name="1"></a>
# ## 1 - Import Packages
#
# We'll make use of the following packages:
# - `numpy` is a package for scientific computing in python.
# - `deque` will be our data structure for our memory buffer.
# - `namedtuple` will be used to store the experience tuples.
# - The `gym` toolkit is a collection of environments that can be used to test reinforcement learning algorithms. We should note that in this notebook we are using `gym` version `0.24.0`.
# - `PIL.Image` and `pyvirtualdisplay` are needed to render the Lunar Lander environment.
# - We will use several modules from the `tensorflow.keras` framework for building deep learning models.
# - `utils_A1` is a module that contains helper functions for this assignment. You do not need to modify the code in this file.
#
# Run the cell below to import all the necessary packages.

# %%
## Might need these
# !pip install swig
# !pip install gymnasium[box2d]
# !pip install pyvirtualdisplay
# !pip install tensorflow
# !pip install Box2D
# !apt install xvfb
import gymnasium as gym

# %%
import time
from collections import deque, namedtuple
import numpy as np
import PIL.Image
import tensorflow as tf
import utils_A1
from IPython.display import Image
import moviepy.editor
import imageio

from pyvirtualdisplay import Display
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.losses import MSE
from tensorflow.keras.optimizers import Adam

# %%
# Set up a virtual display to render the Lunar Lander environment.
Display(visible=0, size=(840, 480)).start();

# Set the random seed for TensorFlow.
tf.random.set_seed(utils_A1.SEED)

# %% [markdown]
# <a name="2"></a>
# ## 2 - Hyperparameters
#
# Run the cell below to set the hyperparameters.

# %%
MEMORY_SIZE = 100_000     # size of memory buffer.
GAMMA = 0.995             # discount factor.
ALPHA = 1e-3              # learning rate.
NUM_STEPS_FOR_UPDATE = 4  # perform a learning update every C time steps.

# %% [markdown]
# <a name="3"></a>
# ## 3 - The Lunar Lander Environment
#
# In this notebook we will be using [OpenAI's Gym Library](https://www.gymlibrary.dev/). The Gym library provides a wide variety of environments for reinforcement learning. To put it simply, an environment represents a problem or task to be solved. In this notebook, we will try to solve the Lunar Lander environment using reinforcement learning.
#
# The goal of the Lunar Lander environment is to land the lunar lander safely on the landing pad on the surface of the moon. The landing pad is designated by two flag poles and it is always at coordinates `(0,0)` but the lander is also allowed to land outside of the landing pad. The lander starts at the top center of the environment with a random initial force applied to its center of mass and has infinite fuel. The environment is considered solved if you get `200` points.

# %%
Image('lunar_lander.gif')

# %% [markdown]
# <a name="3.1"></a>
# ### 3.1 Action Space
#
# The agent has four discrete actions available:
#
# * Do nothing.
# * Fire right engine.
# * Fire main engine.
# * Fire left engine.
#
# Each action has a corresponding numerical value:
#
# ```python
# Do nothing = 0
# Fire right engine = 1
# Fire main engine = 2
# Fire left engine = 3
# ```
#
# <a name="3.2"></a>
# ### 3.2 Observation Space
#
# The agent's observation space consists of a state vector with 8 variables:
#
# * Its $(x,y)$ coordinates. The landing pad is always at coordinates $(0,0)$.
# * Its linear velocities $(\dot x,\dot y)$.
# * Its angle $\theta$.
# * Its angular velocity $\dot \theta$.
# * Two booleans, $l$ and $r$, that represent whether each leg is in contact with the ground or not.
#
# <a name="3.3"></a>
# ### 3.3 Rewards
#
# The Lunar Lander environment has the following reward system:
#
# * Landing on the landing pad and coming to rest is about 100-140 points.
# * If the lander moves away from the landing pad, it loses reward.
# * If the lander crashes, it receives -100 points.
# * If the lander comes to rest, it receives +100 points.
# * Each leg with ground contact is +10 points.
# * Firing the main engine is -0.3 points each frame.
# * Firing the side engine is -0.03 points each frame.
#
# <a name="3.4"></a>
# ### 3.4 Episode Termination
#
# An episode ends (i.e the environment enters a terminal state) if:
#
# * The lunar lander crashes (i.e if the body of the lunar lander comes in contact with the surface of the moon).
#
# * The absolute value of the lander's $x$-coordinate is greater than 1 (i.e. it goes beyond the left or right border)
#
# You can check out the [Open AI Gym documentation](https://www.gymlibrary.dev/environments/box2d/lunar_lander/) for a full description of the environment.

# %% [markdown]
# <a name="4"></a>
# ## 4 - Load the Environment
#
# We start by loading the `LunarLander-v2` environment from the `gym` library by using the `.make()` method. `LunarLander-v2` is the latest version of the Lunar Lander environment and you can read about its version history in the [Open AI Gym documentation](https://www.gymlibrary.dev/environments/box2d/lunar_lander/#version-history).

# %%
env = gym.make('LunarLander-v3', render_mode="rgb_array")

# %% [markdown]
# Once we load the environment we use the `.reset()` method to reset the environment to the initial state. The lander starts at the top center of the environment and we can render the first frame of the environment by using the `.render()` method.

# %%
env.reset()
env.render()

# %% [markdown]
# In order to build our neural network later on we need to know the size of the state vector and the number of valid actions. We can get this information from our environment by using the `.observation_space.shape` and `action_space.n` methods, respectively.

# %%
state_size = env.observation_space.shape
num_actions = env.action_space.n

print('State Shape:', state_size)
print('Number of actions:', num_actions)

# %%
moviepy.editor.ipython_display("lunar_lander.mp4")

# %% [markdown]
# <a name="5"></a>
# ## 5 - Interacting with the Gym Environment
#
# The Gym library implements the standard “agent-environment loop” formalism:
#
# <!-- <br>
# <center>
# <video src = "./rl_formalism.m4v" width="840" height="480" controls autoplay loop poster="./images/rl_formalism.png"> </video>
# <figcaption style = "text-align:center; font-style:italic">Fig 2. Agent-environment Loop Formalism.</figcaption>
# </center>
# <br> -->
#
#
# In the standard “agent-environment loop” formalism, an agent interacts with the environment in discrete time steps $t=0,1,2,...$. At each time step $t$, the agent uses a policy $\pi$ to select an action $A_t$ based on its observation of the environment's state $S_t$. The agent receives a numerical reward $R_t$ and on the next time step, moves to a new state $S_{t+1}$.
#
# <a name="5.1"></a>
# ### 5.1 Exploring the Environment's Dynamics
#
# In Open AI's Gym environments, we use the `.step()` method to run a single time step of the environment's dynamics. In the version of `gym` that we are using the `.step()` method accepts an action and returns four values:
#
# * `observation` (**object**): an environment-specific object representing your observation of the environment. In the Lunar Lander environment this corresponds to a numpy array containing the positions and velocities of the lander as described in section [3.2 Observation Space](#3.2).
#
#
# * `reward` (**float**): amount of reward returned as a result of taking the given action. In the Lunar Lander environment this corresponds to a float of type `numpy.float64` as described in section [3.3 Rewards](#3.3).
#
#
# * `done` (**boolean**): When done is `True`, it indicates the episode has terminated and it’s time to reset the environment.
#
#
# * `info` (**dictionary**): diagnostic information useful for debugging. We won't be using this variable in this notebook but it is shown here for completeness.
#
# To begin an episode, we need to reset the environment to an initial state. We do this by using the `.reset()` method.

# %%
# Reset the environment and get the initial state.
initial_state = env.reset()

# %% [markdown]
# Once the environment is reset, the agent can start taking actions in the environment by using the `.step()` method. Note that the agent can only take one action per time step.
#
# In the cell below you can select different actions and see how the returned values change depending on the action taken. Remember that in this environment the agent has four discrete actions available and we specify them in code by using their corresponding numerical value:
#
# ```python
# Do nothing = 0
# Fire right engine = 1
# Fire main engine = 2
# Fire left engine = 3
# ```

# %%
# Select an action.
action = 0

# Run a single time step of the environment's dynamics with the given action.
next_state, reward, done, _, _ = env.step(action)

# Display table with values. All values are displayed to 3 decimal places.
utils_A1.display_table(initial_state, action, next_state, reward, done)

# %% [markdown]
# In practice, when we train the agent we use a loop to allow the agent to take many consecutive actions during an episode.

# %% [markdown]
# <a name="6"></a>
# ## 6 - Deep Q-Learning
#
# In cases where both the state and action space are discrete we can estimate the action-value function iteratively by using the Bellman equation:
#
# $$
# Q_{i+1}(s,a) = R + \gamma \max_{a'}Q_i(s',a')
# $$
#
# This iterative method converges to the optimal action-value function $Q^*(s,a)$ as $i\to\infty$. This means that the agent just needs to gradually explore the state-action space and keep updating the estimate of $Q(s,a)$ until it converges to the optimal action-value function $Q^*(s,a)$. However, in cases where the state space is continuous it becomes practically impossible to explore the entire state-action space. Consequently, this also makes it practically impossible to gradually estimate $Q(s,a)$ until it converges to $Q^*(s,a)$.
#
# In the Deep $Q$-Learning, we solve this problem by using a neural network to estimate the action-value function $Q(s,a)\approx Q^*(s,a)$. We call this neural network a $Q$-Network and it can be trained by adjusting its weights at each iteration to minimize the mean-squared error in the Bellman equation.
#
# Unfortunately, using neural networks in reinforcement learning to estimate action-value functions has proven to be highly unstable. Luckily, there's a couple of techniques that can be employed to avoid instabilities. These techniques consist of using a ***Target Network*** and ***Experience Replay***. We will explore these two techniques in the following sections.

# %% [markdown]
# <a name="6.1"></a>
# ### 6.1 Target Network
#
# We can train the $Q$-Network by adjusting it's weights at each iteration to minimize the mean-squared error in the Bellman equation, where the target values are given by:
#
# $$
# y = R + \gamma \max_{a'}Q(s',a';w)
# $$
#
# where $w$ are the weights of the $Q$-Network. This means that we are adjusting the weights $w$ at each iteration to minimize the following error:
#
# $$
# \overbrace{\underbrace{R + \gamma \max_{a'}Q(s',a'; w)}_{\rm {y~target}} - Q(s,a;w)}^{\rm {Error}}
# $$
#
# Notice that this forms a problem because the $y$ target is changing on every iteration. Having a constantly moving target can lead to oscillations and instabilities. To avoid this, we can create
# a separate neural network for generating the $y$ targets. We call this separate neural network the **target $\hat Q$-Network** and it will have the same architecture as the original $Q$-Network. By using the target $\hat Q$-Network, the above error becomes:
#
# $$
# \overbrace{\underbrace{R + \gamma \max_{a'}\hat{Q}(s',a'; w^-)}_{\rm {y~target}} - Q(s,a;w)}^{\rm {Error}}
# $$
#
# where $w^-$ and $w$ are the weights the target $\hat Q$-Network and $Q$-Network, respectively.
#
# In practice, we will use the following algorithm: every $C$ time steps we will use the $\hat Q$-Network to generate the $y$ targets and update the weights of the target $\hat Q$-Network using the weights of the $Q$-Network. We will update the weights $w^-$ of the the target $\hat Q$-Network using a **soft update**. This means that we will update the weights $w^-$ using the following rule:
#
# $$
# w^-\leftarrow \tau w + (1 - \tau) w^-
# $$
#
# where $\tau\ll 1$. By using the soft update, we are ensuring that the target values, $y$, change slowly, which greatly improves the stability of our learning algorithm.

# %% [markdown]
# <a name="ex01"></a>
# ### Exercise 1
#
# In this exercise you will create the $Q$ and target $\hat Q$ networks and set the optimizer. Remember that the Deep $Q$-Network (DQN) is a neural network that approximates the action-value function $Q(s,a)\approx Q^*(s,a)$. It does this by learning how to map states to $Q$ values.
#
# To solve the Lunar Lander environment, we are going to employ a DQN with the following architecture:
#
# * An `Input` layer that takes `state_size` as input.
#
# * A `Dense` layer with `64` units and a `relu` activation function.
#
# * A `Dense` layer with `64` units and a `relu` activation function.
#
# * A `Dense` layer with `num_actions` units and a `linear` activation function. This will be the output layer of our network.
#
#
# In the cell below you should create the $Q$-Network and the target $\hat Q$-Network using the model architecture described above. Remember that both the $Q$-Network and the target $\hat Q$-Network have the same architecture.
#
# Lastly, you should set `Adam` as the optimizer with a learning rate equal to `ALPHA`. Recall that `ALPHA` was defined in the [Hyperparameters](#2) section. We should note that for this exercise you should use the already imported packages:
# ```python
# from tensorflow.keras.layers import Dense, Input
# from tensorflow.keras.optimizers import Adam
# ```

# %%
# Create the Q-Network.
q_network = Sequential([

    Input(shape=state_size),
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=num_actions, activation='linear')

    ])

# Create the target Q^-Network.
target_q_network = Sequential([

    Input(shape=state_size),
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=num_actions, activation='linear')

    ])

optimizer = Adam(learning_rate=ALPHA)

# %% [markdown]
# <a name="6.2"></a>
# ### 6.2 Experience Replay
#
# When an agent interacts with the environment, the states, actions, and rewards the agent experiences are sequential by nature. If the agent tries to learn from these consecutive experiences it can run into problems due to the strong correlations between them. To avoid this, we employ a technique known as **Experience Replay** to generate uncorrelated experiences for training our agent. Experience replay consists of storing the agent's experiences (i.e the states, actions, and rewards the agent receives) in a memory buffer and then sampling a random mini-batch of experiences from the buffer to do the learning. The experience tuples $(S_t, A_t, R_t, S_{t+1})$ will be added to the memory buffer at each time step as the agent interacts with the environment.
#
# For convenience, we will store the experiences as named tuples.

# %%
# Store experiences as named tuples.
experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])

# %% [markdown]
# By using experience replay we avoid problematic correlations, oscillations and instabilities. In addition, experience replay also allows the agent to potentially use the same experience in multiple weight updates, which increases data efficiency.

# %% [markdown]
# <a name="7"></a>
# ## 7 - Deep Q-Learning Algorithm with Experience Replay
#
# Now that we know all the techniques that we are going to use, we can put them together to arrive at the Deep Q-Learning Algorithm With Experience Replay.

# %%
Image("deep_q_algorithm.png")

# %% [markdown]
# <a name="ex02"></a>
# ### Exercise 2
#
# In this exercise you will implement line ***12*** of the algorithm outlined in *Fig 3* above and you will also compute the loss between the $y$ targets and the $Q(s,a)$ values. In the cell below, complete the `compute_loss` function by setting the $y$ targets equal to:
#
# $$
# \begin{equation}
#     y_j =
#     \begin{cases}
#       R_j & \text{if episode terminates at step  } j+1\\
#       R_j + \gamma \max_{a'}\hat{Q}(s_{j+1},a') & \text{otherwise}\\
#     \end{cases}
# \end{equation}
# $$
#
# Here are a couple of things to note:
#
# * The `compute_loss` function takes in a mini-batch of experience tuples. This mini-batch of experience tuples is unpacked to extract the `states`, `actions`, `rewards`, `next_states`, and `done_vals`. You should keep in mind that these variables are *TensorFlow Tensors* whose size will depend on the mini-batch size. For example, if the mini-batch size is `64` then both `rewards` and `done_vals` will be TensorFlow Tensors with `64` elements.
#
#
# * Using `if/else` statements to set the $y$ targets will not work when the variables are tensors with many elements. However, notice that you can use the `done_vals` to implement the above in a single line of code. To do this, recall that the `done` variable is a Boolean variable that takes the value `True` when an episode terminates at step $j+1$ and it is `False` otherwise. Taking into account that a Boolean value of `True` has the numerical value of `1` and a Boolean value of `False` has the numerical value of `0`, you can use the factor `(1 - done_vals)` to implement the above in a single line of code. Here's a hint: notice that `(1 - done_vals)` has a value of `0` when `done_vals` is `True` and a value of `1` when `done_vals` is `False`.
#
# Lastly, compute the loss by calculating the Mean-Squared Error (`MSE`) between the `y_targets` and the `q_values`. To calculate the mean-squared error you should use the already imported package `MSE`:
# ```python
# from tensorflow.keras.losses import MSE
# ```

# %%
def compute_loss(experiences, gamma, q_network, target_q_network):
    """
    Calculates the loss.

    Args:
      experiences: (tuple) tuple of ["state", "action", "reward", "next_state", "done"] namedtuples
      gamma: (float) The discount factor.
      q_network: (tf.keras.Sequential) Keras model for predicting the q_values
      target_q_network: (tf.keras.Sequential) Keras model for predicting the targets

    Returns:
      loss: (TensorFlow Tensor(shape=(0,), dtype=int32)) the Mean-Squared Error between
            the y targets and the Q(s,a) values.
    """

    # Unpack the mini-batch of experience tuples.
    states, actions, rewards, next_states, done_vals = experiences

    # Compute max Q^(s,a).
    max_qsa = tf.reduce_max(target_q_network(next_states), axis=-1)

    # Set y = R if episode terminates, otherwise set y = R + γ max Q^(s,a).
    ### START CODE HERE ###
    y_targets = rewards + (gamma * max_qsa * (1 - done_vals))
    ### END CODE HERE ###

    # Get the q_values.
    q_values = q_network(states)
    q_values = tf.gather_nd(q_values, tf.stack([tf.range(q_values.shape[0]),
                                                tf.cast(actions, tf.int32)], axis=1))

    # Compute the loss.
    loss = MSE(y_targets, q_values)

    return loss

# %% [markdown]
# <a name="8"></a>
# ## 8 - Update the Network Weights
#
# We will use the `agent_learn` function below to implement lines ***12 -14*** of the algorithm outlined in [Fig 3](#7). The `agent_learn` function will update the weights of the $Q$ and target $\hat Q$ networks using a custom training loop. Because we are using a custom training loop we need to retrieve the gradients via a `tf.GradientTape` instance, and then call `optimizer.apply_gradients()` to update the weights of our $Q$-Network. Note that we are also using the `@tf.function` decorator to increase performance. Without this decorator our training will take twice as long. If you would like to know more about how to increase performance with `@tf.function` take a look at the [TensorFlow documentation](https://www.tensorflow.org/guide/function).
#
# The last line of this function updates the weights of the target $\hat Q$-Network using a [soft update](#6.1). If you want to know how this is implemented in code we encourage you to take a look at the `utils_A1.update_target_network` function in the `utils_A1` module.

# %%
@tf.function
def agent_learn(experiences, gamma):
    """
    Updates the weights of the Q networks.

    Args:
      experiences: (tuple) tuple of ["state", "action", "reward", "next_state", "done"] namedtuples
      gamma: (float) The discount factor.

    """

    # Calculate the loss.
    with tf.GradientTape() as tape:
        loss = compute_loss(experiences, gamma, q_network, target_q_network)

    # Get the gradients of the loss with respect to the weights.
    gradients = tape.gradient(loss, q_network.trainable_variables)

    # Update the weights of the q_network.
    optimizer.apply_gradients(zip(gradients, q_network.trainable_variables))

    # update the weights of target q_network.
    utils_A1.update_target_network(q_network, target_q_network)

# %% [markdown]
# <a name="9"></a>
# ## 9 - Train the Agent
#
# We are now ready to train our agent to solve the Lunar Lander environment. In the cell below we will implement the algorithm in [Fig 3](#7) line by line (please note that we have included the same algorithm below for easy reference. This will prevent you from scrolling up and down the notebook):
#
# * **Line 1**: We initialize the `memory_buffer` with a capacity of $N =$ `MEMORY_SIZE`. Notice that we are using a `deque` as the data structure for our `memory_buffer`.
#
#
# * **Line 2**: We skip this line since we already initialized the `q_network` in [Exercise 1](#ex01).
#
#
# * **Line 3**: We initialize the `target_q_network` by setting its weights to be equal to those of the `q_network`.
#
#
# * **Line 4**: We start the outer loop. Notice that we have set $M =$ `num_episodes = 2000`. This number is reasonable because the agent should be able to solve the Lunar Lander environment in less than `2000` episodes using this notebook's default parameters.
#
#
# * **Line 5**: We use the `.reset()` method to reset the environment to the initial state and get the initial state.
#
#
# * **Line 6**: We start the inner loop. Notice that we have set $T =$ `max_num_timesteps = 1000`. This means that the episode will automatically terminate if the episode hasn't terminated after `1000` time steps.
#
#
# * **Line 7**: The agent observes the current `state` and chooses an `action` using an $\epsilon$-greedy policy. Our agent starts out using a value of $\epsilon =$ `epsilon = 1` which yields an $\epsilon$-greedy policy that is equivalent to the equiprobable random policy. This means that at the beginning of our training, the agent is just going to take random actions regardless of the observed `state`. As training progresses we will decrease the value of $\epsilon$ slowly towards a minimum value using a given $\epsilon$-decay rate. We want this minimum value to be close to zero because a value of $\epsilon = 0$ will yield an $\epsilon$-greedy policy that is equivalent to the greedy policy. This means that towards the end of training, the agent will lean towards selecting the `action` that it believes (based on its past experiences) will maximize $Q(s,a)$. We will set the minimum $\epsilon$ value to be `0.01` and not exactly 0 because we always want to keep a little bit of exploration during training. If you want to know how this is implemented in code we encourage you to take a look at the `utils_A1.get_action` function in the `utils_A1` module.
#
#
# * **Line 8**: We use the `.step()` method to take the given `action` in the environment and get the `reward` and the `next_state`.
#
#
# * **Line 9**: We store the `experience(state, action, reward, next_state, done)` tuple in our `memory_buffer`. Notice that we also store the `done` variable so that we can keep track of when an episode terminates. This allowed us to set the $y$ targets in [Exercise 2](#ex02).
#
#
# * **Line 10**: We check if the conditions are met to perform a learning update. We do this by using our custom `utils_A1.check_update_conditions` function. This function checks if $C =$ `NUM_STEPS_FOR_UPDATE = 4` time steps have occured and if our `memory_buffer` has enough experience tuples to fill a mini-batch. For example, if the mini-batch size is `64`, then our `memory_buffer` should have more than `64` experience tuples in order to pass the latter condition. If the conditions are met, then the `utils_A1.check_update_conditions` function will return a value of `True`, otherwise it will return a value of `False`.
#
#
# * **Lines 11 - 14**: If the `update` variable is `True` then we perform a learning update. The learning update consists of sampling a random mini-batch of experience tuples from our `memory_buffer`, setting the $y$ targets, performing gradient descent, and updating the weights of the networks. We will use the `agent_learn` function we defined in [Section 8](#8) to perform the latter 3.
#
#
# * **Line 15**: At the end of each iteration of the inner loop we set `next_state` as our new `state` so that the loop can start again from this new state. In addition, we check if the episode has reached a terminal state (i.e we check if `done = True`). If a terminal state has been reached, then we break out of the inner loop.
#
#
# * **Line 16**: At the end of each iteration of the outer loop we update the value of $\epsilon$, and check if the environment has been solved. We consider that the environment has been solved if the agent receives an average of `200` points in the last `100` episodes. If the environment has not been solved we continue the outer loop and start a new episode.
#
# Finally, we wanted to note that we have included some extra variables to keep track of the total number of points the agent received in each episode. This will help us determine if the agent has solved the environment and it will also allow us to see how our agent performed during training. We also use the `time` module to measure how long the training takes.
#
#
# **Note:** With this notebook's default parameters, the following cell takes between 10 to 15 minutes to run.

# %%
Image("deep_q_algorithm.png")

# %%
def get_experiences(memory_buffer):
    """
    Returns a random sample of experience tuples drawn from the memory buffer.

    Retrieves a random sample of experience tuples from the given memory_buffer and
    returns them as TensorFlow Tensors. The size of the random sample is determined by
    the mini-batch size (MINIBATCH_SIZE).

    Args:
        memory_buffer (deque):
            A deque containing experiences. The experiences are stored in the memory
            buffer as namedtuples: namedtuple("Experience", field_names=["state",
            "action", "reward", "next_state", "done"]).

    Returns:
        A tuple (states, actions, rewards, next_states, done_vals) where:

            - states are the starting states of the agent.
            - actions are the actions taken by the agent from the starting states.
            - rewards are the rewards received by the agent after taking the actions.
            - next_states are the new states of the agent after taking the actions.
            - done_vals are the boolean values indicating if the episode ended.

        All tuple elements are TensorFlow Tensors whose shape is determined by the
        mini-batch size and the given Gym environment. For the Lunar Lander environment
        the states and next_states will have a shape of [MINIBATCH_SIZE, 8] while the
        actions, rewards, and done_vals will have a shape of [MINIBATCH_SIZE]. All
        TensorFlow Tensors have elements with dtype=tf.float32.
    """

    experiences = random.sample(memory_buffer, k=MINIBATCH_SIZE)

    states = tf.convert_to_tensor(
        np.array([e.state for e in experiences if e is not None]), dtype=tf.float32
    )
    actions = tf.convert_to_tensor(
        np.array([e.action for e in experiences if e is not None]), dtype=tf.float32
    )
    rewards = tf.convert_to_tensor(
        np.array([e.reward for e in experiences if e is not None]), dtype=tf.float32
    )
    next_states = tf.convert_to_tensor(
        np.array([e.next_state for e in experiences if e is not None]), dtype=tf.float32
    )
    done_vals = tf.convert_to_tensor(
        np.array([e.done for e in experiences if e is not None]).astype(np.uint8),
        dtype=tf.float32,
    )
    done_vals = tf.convert_to_tensor(
        np.array([e.done for e in experiences if e is not None]).astype(np.uint8),
        dtype=tf.float32,
    )
    return (states, actions, rewards, next_states, done_vals)

# %%
import random
SEED = 0              # seed for pseudo-random number generator
MINIBATCH_SIZE = 64   # mini-batch size
TAU = 1e-3            # soft update parameter
E_DECAY = 0.995       # ε decay rate for ε-greedy policy
E_MIN = 0.01          # minimum ε value for ε-greedy policy

# %%
start = time.time()

num_episodes = 2000
max_num_timesteps = 1000

total_point_history = []

num_p_av = 100    # number of total points to use for averaging.
epsilon = 1.0     # initial ε value for ε-greedy policy.

# Create a memory buffer D with capacity N.
memory_buffer = deque(maxlen=MEMORY_SIZE)

# Set the target network weights equal to the Q-Network weights.
target_q_network.set_weights(q_network.get_weights())

for i in range(num_episodes):

    # Reset the environment to the initial state and get the initial state.
    state = env.reset()
    total_points = 0

    for t in range(max_num_timesteps):

        # From the current state S choose an action A using an ε-greedy policy.
        if type(state) == tuple:
          state_qn = np.expand_dims(state[0], axis=0)
        elif state.shape==(8,):
          state_qn = np.expand_dims(state, axis=0)
        else:
          state_qn = np.expand_dims(state, axis=0)

           # state needs to be the right shape for the q_network.
        state_qn = state_qn.reshape((1, 8))
        q_values = q_network(state_qn)
        action = utils_A1.get_action(q_values, epsilon)

        # Take action A and receive reward R and the next state S'.
        next_state, reward, done, _, _ = env.step(action)

        # Store experience tuple (S,A,R,S') in the memory buffer.
        # We store the done variable as well for convenience.
        memory_buffer.append(experience(state_qn, action, reward, next_state, done))

        # Only update the network every NUM_STEPS_FOR_UPDATE time steps.
        update = utils_A1.check_update_conditions(t, NUM_STEPS_FOR_UPDATE, memory_buffer)
        if update:
          try:
            # Sample random mini-batch of experience tuples (S,A,R,S') from D.
            experiences = get_experiences(memory_buffer)

            # Set the y targets, perform a gradient descent step,
            # and update the network weights.
            agent_learn(experiences, GAMMA)
          except:
            print('still') # CAN SOMEONE FIGURE OUT THIS ISSUE???
        state = next_state.copy()
        total_points += reward

        if done:
            break

    total_point_history.append(total_points)
    av_latest_points = np.mean(total_point_history[-num_p_av:])

    # Update the ε value.
    epsilon = utils_A1.get_new_eps(epsilon)

    print(f"\rEpisode {i+1} | Total point average of the last {num_p_av} episodes: {av_latest_points:.2f}", end="")

    if (i+1) % num_p_av == 0:
        print(f"\rEpisode {i+1} | Total point average of the last {num_p_av} episodes: {av_latest_points:.2f}")

    # We will consider that the environment is solved if we get an
    # average of 200 points in the last 100 episodes.
    if av_latest_points >= 200.0:
        print(f"\n\nEnvironment solved in {i+1} episodes!")
        q_network.save('lunar_lander_model.h5')
        break

tot_time = time.time() - start

print(f"\nTotal Runtime: {tot_time:.2f} s ({(tot_time/60):.2f} min)")
# Out:
# Streaming output truncated to the last 5000 lines.
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 156 | Total point average of the last 100 episodes: -377.45still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 157 | Total point average of the last 100 episodes: -377.41still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 158 | Total point average of the last 100 episodes: -375.43still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 159 | Total point average of the last 100 episodes: -377.60still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 160 | Total point average of the last 100 episodes: -376.87still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 161 | Total point average of the last 100 episodes: -379.55still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 162 | Total point average of the last 100 episodes: -379.25still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 163 | Total point average of the last 100 episodes: -380.00still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 164 | Total point average of the last 100 episodes: -383.47still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 165 | Total point average of the last 100 episodes: -383.14still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 166 | Total point average of the last 100 episodes: -380.67still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 167 | Total point average of the last 100 episodes: -378.77still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 168 | Total point average of the last 100 episodes: -380.40still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 169 | Total point average of the last 100 episodes: -384.65still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 170 | Total point average of the last 100 episodes: -384.64still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 171 | Total point average of the last 100 episodes: -385.72still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 172 | Total point average of the last 100 episodes: -388.43still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 173 | Total point average of the last 100 episodes: -391.03still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 174 | Total point average of the last 100 episodes: -390.80still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 175 | Total point average of the last 100 episodes: -390.53still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 176 | Total point average of the last 100 episodes: -390.87still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 177 | Total point average of the last 100 episodes: -394.59still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 178 | Total point average of the last 100 episodes: -392.97still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 179 | Total point average of the last 100 episodes: -395.07still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 180 | Total point average of the last 100 episodes: -393.68still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 181 | Total point average of the last 100 episodes: -397.11still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 182 | Total point average of the last 100 episodes: -402.20still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 183 | Total point average of the last 100 episodes: -400.39still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 184 | Total point average of the last 100 episodes: -405.57still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 185 | Total point average of the last 100 episodes: -408.17still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 186 | Total point average of the last 100 episodes: -411.17still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 187 | Total point average of the last 100 episodes: -411.51still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 188 | Total point average of the last 100 episodes: -413.74still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 189 | Total point average of the last 100 episodes: -412.40still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 190 | Total point average of the last 100 episodes: -410.62still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 191 | Total point average of the last 100 episodes: -409.53still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 192 | Total point average of the last 100 episodes: -409.38still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 193 | Total point average of the last 100 episodes: -412.49still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 194 | Total point average of the last 100 episodes: -413.61still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 195 | Total point average of the last 100 episodes: -415.65still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 196 | Total point average of the last 100 episodes: -419.61still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 197 | Total point average of the last 100 episodes: -422.20still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 198 | Total point average of the last 100 episodes: -423.03still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 199 | Total point average of the last 100 episodes: -425.76still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 200 | Total point average of the last 100 episodes: -427.89
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 201 | Total point average of the last 100 episodes: -428.76still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 202 | Total point average of the last 100 episodes: -430.95still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 203 | Total point average of the last 100 episodes: -435.38still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 204 | Total point average of the last 100 episodes: -436.29still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 205 | Total point average of the last 100 episodes: -433.09still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 206 | Total point average of the last 100 episodes: -434.63still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 207 | Total point average of the last 100 episodes: -436.70still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 208 | Total point average of the last 100 episodes: -437.11still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 209 | Total point average of the last 100 episodes: -437.90still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 210 | Total point average of the last 100 episodes: -439.93still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 211 | Total point average of the last 100 episodes: -440.94still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 212 | Total point average of the last 100 episodes: -442.58still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 213 | Total point average of the last 100 episodes: -444.90still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 214 | Total point average of the last 100 episodes: -440.22still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 215 | Total point average of the last 100 episodes: -438.09still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 216 | Total point average of the last 100 episodes: -438.81still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 217 | Total point average of the last 100 episodes: -442.21still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 218 | Total point average of the last 100 episodes: -445.31still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 219 | Total point average of the last 100 episodes: -444.30still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 220 | Total point average of the last 100 episodes: -442.69still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 221 | Total point average of the last 100 episodes: -445.23still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 222 | Total point average of the last 100 episodes: -447.26still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 223 | Total point average of the last 100 episodes: -451.64still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 224 | Total point average of the last 100 episodes: -453.75still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 225 | Total point average of the last 100 episodes: -452.61still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 226 | Total point average of the last 100 episodes: -451.52still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 227 | Total point average of the last 100 episodes: -454.48still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 228 | Total point average of the last 100 episodes: -457.34still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 229 | Total point average of the last 100 episodes: -457.15still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 230 | Total point average of the last 100 episodes: -456.88still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 231 | Total point average of the last 100 episodes: -460.74still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 232 | Total point average of the last 100 episodes: -462.40still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 233 | Total point average of the last 100 episodes: -461.89still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 234 | Total point average of the last 100 episodes: -464.23still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 235 | Total point average of the last 100 episodes: -464.69still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 236 | Total point average of the last 100 episodes: -466.90still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 237 | Total point average of the last 100 episodes: -466.60still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 238 | Total point average of the last 100 episodes: -465.86still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 239 | Total point average of the last 100 episodes: -462.31still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 240 | Total point average of the last 100 episodes: -463.34still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 241 | Total point average of the last 100 episodes: -462.51still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 242 | Total point average of the last 100 episodes: -463.88still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 243 | Total point average of the last 100 episodes: -466.74still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 244 | Total point average of the last 100 episodes: -467.92still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 245 | Total point average of the last 100 episodes: -467.05still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 246 | Total point average of the last 100 episodes: -466.77still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 247 | Total point average of the last 100 episodes: -471.81still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 248 | Total point average of the last 100 episodes: -475.11still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 249 | Total point average of the last 100 episodes: -477.32still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 250 | Total point average of the last 100 episodes: -478.66still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 251 | Total point average of the last 100 episodes: -479.40still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 252 | Total point average of the last 100 episodes: -483.34still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 253 | Total point average of the last 100 episodes: -483.82still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 254 | Total point average of the last 100 episodes: -484.41still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 255 | Total point average of the last 100 episodes: -485.45still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 256 | Total point average of the last 100 episodes: -482.04still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 257 | Total point average of the last 100 episodes: -487.64still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 258 | Total point average of the last 100 episodes: -489.62still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 259 | Total point average of the last 100 episodes: -491.10still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 260 | Total point average of the last 100 episodes: -492.11still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 261 | Total point average of the last 100 episodes: -493.85still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 262 | Total point average of the last 100 episodes: -493.42still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 263 | Total point average of the last 100 episodes: -500.52still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 264 | Total point average of the last 100 episodes: -500.92still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 265 | Total point average of the last 100 episodes: -500.18still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 266 | Total point average of the last 100 episodes: -503.10still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 267 | Total point average of the last 100 episodes: -502.51still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 268 | Total point average of the last 100 episodes: -503.92still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 269 | Total point average of the last 100 episodes: -501.04still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 270 | Total point average of the last 100 episodes: -506.40still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 271 | Total point average of the last 100 episodes: -508.69still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 272 | Total point average of the last 100 episodes: -508.12still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 273 | Total point average of the last 100 episodes: -505.55still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 274 | Total point average of the last 100 episodes: -506.26still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 275 | Total point average of the last 100 episodes: -506.68still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 276 | Total point average of the last 100 episodes: -506.09still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 277 | Total point average of the last 100 episodes: -504.90still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 278 | Total point average of the last 100 episodes: -506.27still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 279 | Total point average of the last 100 episodes: -508.62still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 280 | Total point average of the last 100 episodes: -509.52still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 281 | Total point average of the last 100 episodes: -507.05still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 282 | Total point average of the last 100 episodes: -505.51still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 283 | Total point average of the last 100 episodes: -513.00still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 284 | Total point average of the last 100 episodes: -507.74still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 285 | Total point average of the last 100 episodes: -507.80still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 286 | Total point average of the last 100 episodes: -507.91still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 287 | Total point average of the last 100 episodes: -506.18still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 288 | Total point average of the last 100 episodes: -505.66still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 289 | Total point average of the last 100 episodes: -504.75still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 290 | Total point average of the last 100 episodes: -507.05still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 291 | Total point average of the last 100 episodes: -513.60still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 292 | Total point average of the last 100 episodes: -513.14still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 293 | Total point average of the last 100 episodes: -514.37still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 294 | Total point average of the last 100 episodes: -516.31still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 295 | Total point average of the last 100 episodes: -516.15still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 296 | Total point average of the last 100 episodes: -516.01still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 297 | Total point average of the last 100 episodes: -514.11still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 298 | Total point average of the last 100 episodes: -512.90still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 299 | Total point average of the last 100 episodes: -512.33still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 300 | Total point average of the last 100 episodes: -519.07
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 301 | Total point average of the last 100 episodes: -520.14still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 302 | Total point average of the last 100 episodes: -520.19still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 303 | Total point average of the last 100 episodes: -519.07still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 304 | Total point average of the last 100 episodes: -518.04still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 305 | Total point average of the last 100 episodes: -518.43still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 306 | Total point average of the last 100 episodes: -519.12still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 307 | Total point average of the last 100 episodes: -520.26still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 308 | Total point average of the last 100 episodes: -520.97still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 309 | Total point average of the last 100 episodes: -521.07still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 310 | Total point average of the last 100 episodes: -520.76still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 311 | Total point average of the last 100 episodes: -521.00still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 312 | Total point average of the last 100 episodes: -519.27still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 313 | Total point average of the last 100 episodes: -518.53still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 314 | Total point average of the last 100 episodes: -518.85still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 315 | Total point average of the last 100 episodes: -520.00still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 316 | Total point average of the last 100 episodes: -521.71still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 317 | Total point average of the last 100 episodes: -520.22still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 318 | Total point average of the last 100 episodes: -520.74still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 319 | Total point average of the last 100 episodes: -520.05still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 320 | Total point average of the last 100 episodes: -521.71still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 321 | Total point average of the last 100 episodes: -522.46still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 322 | Total point average of the last 100 episodes: -522.48still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 323 | Total point average of the last 100 episodes: -520.93still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 324 | Total point average of the last 100 episodes: -516.10still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 325 | Total point average of the last 100 episodes: -515.97still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 326 | Total point average of the last 100 episodes: -518.76still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 327 | Total point average of the last 100 episodes: -520.68still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 328 | Total point average of the last 100 episodes: -525.11still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 329 | Total point average of the last 100 episodes: -525.16still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 330 | Total point average of the last 100 episodes: -526.75still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 331 | Total point average of the last 100 episodes: -521.70still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 332 | Total point average of the last 100 episodes: -525.01still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 333 | Total point average of the last 100 episodes: -524.98still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 334 | Total point average of the last 100 episodes: -525.14still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 335 | Total point average of the last 100 episodes: -533.60still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 336 | Total point average of the last 100 episodes: -533.68still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 337 | Total point average of the last 100 episodes: -536.62still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 338 | Total point average of the last 100 episodes: -536.30still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 339 | Total point average of the last 100 episodes: -535.09still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 340 | Total point average of the last 100 episodes: -537.05still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 341 | Total point average of the last 100 episodes: -537.47still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 342 | Total point average of the last 100 episodes: -537.99still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 343 | Total point average of the last 100 episodes: -537.14still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 344 | Total point average of the last 100 episodes: -538.75still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 345 | Total point average of the last 100 episodes: -541.08still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 346 | Total point average of the last 100 episodes: -541.10still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 347 | Total point average of the last 100 episodes: -538.48still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 348 | Total point average of the last 100 episodes: -538.76still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 349 | Total point average of the last 100 episodes: -539.22still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 350 | Total point average of the last 100 episodes: -540.48still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 351 | Total point average of the last 100 episodes: -547.04still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 352 | Total point average of the last 100 episodes: -545.98still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 353 | Total point average of the last 100 episodes: -550.09still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 354 | Total point average of the last 100 episodes: -550.39still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 355 | Total point average of the last 100 episodes: -550.22still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 356 | Total point average of the last 100 episodes: -552.33still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 357 | Total point average of the last 100 episodes: -546.72still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 358 | Total point average of the last 100 episodes: -547.09still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 359 | Total point average of the last 100 episodes: -547.00still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 360 | Total point average of the last 100 episodes: -545.32still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 361 | Total point average of the last 100 episodes: -540.71still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 362 | Total point average of the last 100 episodes: -541.74still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 363 | Total point average of the last 100 episodes: -533.74still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 364 | Total point average of the last 100 episodes: -536.23still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 365 | Total point average of the last 100 episodes: -537.38still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 366 | Total point average of the last 100 episodes: -538.36still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 367 | Total point average of the last 100 episodes: -539.01still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 368 | Total point average of the last 100 episodes: -539.76still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 369 | Total point average of the last 100 episodes: -541.93still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 370 | Total point average of the last 100 episodes: -538.75still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 371 | Total point average of the last 100 episodes: -538.98still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 372 | Total point average of the last 100 episodes: -538.17still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 373 | Total point average of the last 100 episodes: -543.57still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 374 | Total point average of the last 100 episodes: -543.38still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 375 | Total point average of the last 100 episodes: -544.38still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 376 | Total point average of the last 100 episodes: -543.93still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 377 | Total point average of the last 100 episodes: -556.90still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 378 | Total point average of the last 100 episodes: -555.90still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 379 | Total point average of the last 100 episodes: -555.03still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 380 | Total point average of the last 100 episodes: -557.86still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 381 | Total point average of the last 100 episodes: -558.01still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 382 | Total point average of the last 100 episodes: -559.56still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 383 | Total point average of the last 100 episodes: -553.83still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 384 | Total point average of the last 100 episodes: -551.92still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 385 | Total point average of the last 100 episodes: -552.71still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 386 | Total point average of the last 100 episodes: -562.63still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 387 | Total point average of the last 100 episodes: -565.50still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 388 | Total point average of the last 100 episodes: -563.84still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 389 | Total point average of the last 100 episodes: -566.80still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 390 | Total point average of the last 100 episodes: -567.74still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 391 | Total point average of the last 100 episodes: -565.38still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 392 | Total point average of the last 100 episodes: -566.03still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 393 | Total point average of the last 100 episodes: -565.87still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 394 | Total point average of the last 100 episodes: -563.83still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 395 | Total point average of the last 100 episodes: -563.40still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 396 | Total point average of the last 100 episodes: -564.43still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 397 | Total point average of the last 100 episodes: -565.32still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# still
# Episode 398 | Total point average of the last 100 episodes: -566.81still

# %% [markdown]
# We can plot the total point history along with the moving average to see how our agent improved during training. If you want to know about the different plotting options available in the `utils_A1.plot_history` function we encourage you to take a look at the `utils_A1` module.

# %%
# Plot the total point history along with the moving average.
utils_A1.plot_history(total_point_history)

# %% [markdown]
# <a name="10"></a>
# ## 10 - See the Trained Agent In Action
#
# Now that we have trained our agent, we can see it in action. We will use the `utils_A1.create_video` function to create a video of our agent interacting with the environment using the trained $Q$-Network. The `utils_A1.create_video` function uses the `imageio` library to create the video. This library produces some warnings that can be distracting, so, to suppress these warnings we run the code below.

# %%
# Suppress warnings from imageio.
import logging
logging.getLogger().setLevel(logging.ERROR)

# %% [markdown]
# In the cell below we create a video of our agent interacting with the Lunar Lander environment using the trained `q_network`. The video is saved to the `videos` folder with the given `filename`. We use the `utils_A1.embed_mp4` function to embed the video in the Jupyter Notebook so that we can see it here directly without having to download it.
#
# We should note that since the lunar lander starts with a random initial force applied to its center of mass, every time you run the cell below you will see a different video. If the agent was trained properly, it should be able to land the lunar lander in the landing pad every time, regardless of the initial force applied to its center of mass.

# %%
with imageio.get_writer(filename, fps=30) as video:
    done = False
    state = env.reset()
    env.render()
    frame = env.render()
    video.append_data(frame)
    while not done:

        if type(state) == tuple:
          state = np.expand_dims(state[0], axis=0)
        else:
          state = np.expand_dims(state, axis=0)
        try:
          q_values = q_network(state)
          action = np.argmax(q_values.numpy()[0])
          state, _, done, _, _ = env.step(action)
          env.render()
          frame = env.render()
          video.append_data(frame)
        except:
          print('wrong_shape')

# %%
filename = "lunar_lander.mp4"
# import imageio
# create_video(filename, env, q_network)
utils_A1.embed_mp4(filename)

# %% [markdown]
# <a name="11"></a>
# ## 11 - Congratulations!
#
# You have successfully used Deep Q-Learning with Experience Replay to train an agent to land a lunar lander safely on a landing pad on the surface of the moon. Congratulations!

# %% [markdown]
# <a name="12"></a>
# ## 12 - References
#
# If you would like to learn more about Deep Q-Learning, we recommend you check out the following papers.
#
#
# * Mnih, V., Kavukcuoglu, K., Silver, D. et al. Human-level control through deep reinforcement learning. Nature 518, 529–533 (2015).
#
#
# * Lillicrap, T. P., Hunt, J. J., Pritzel, A., et al. Continuous Control with Deep Reinforcement Learning. ICLR (2016).
#
#
# * Mnih, V., Kavukcuoglu, K., Silver, D. et al. Playing Atari with Deep Reinforcement Learning. arXiv e-prints.  arXiv:1312.5602 (2013).
